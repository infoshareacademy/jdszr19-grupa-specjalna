# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ustawienia wyświetlania
pd.set_option('display.max_columns', None)
sns.set(style="whitegrid")

# %% [markdown]
#  1. Struktura danych
#  Czy dane zostały poprawnie wczytane (sprawdzenie .head() i .info())?
#  Ile jest kolumn i wierszy?
#  Jakie są typy danych (int, float, object, datetime)?

# %%
# Wczytanie danych z beneficiary
train_provider = pd.read_csv('Train-1542865627584.csv')

# sprawdzenie head
train_provider.head()
# Out:
#    Provider PotentialFraud
# 0  PRV51001             No
# 1  PRV51003            Yes
# 2  PRV51004             No
# 3  PRV51005            Yes
# 4  PRV51007             No

# %%
# sprawdzenie info
train_provider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   object
# dtypes: object(2)
# memory usage: 84.7+ KB

# %% [markdown]
# Widać że PotentialFraud ma wartości tylko Yes/No to flaga klasyfikacji ("Yes" / "No"), więc idealnie powinna być bool lub category.

# %%
# Konwersja na flagę binarną
train_provider['FraudFlag'] = train_provider['PotentialFraud'].map({'Yes': 1, 'No': 0})

# Sprawdź typy
print(train_provider.dtypes)
# Out:
# Provider          object
# PotentialFraud    object
# FraudFlag          int64
# dtype: object

# %%
train_provider['PotentialFraud'] = train_provider['PotentialFraud'].astype('category')
train_provider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   category
#  2   FraudFlag       5410 non-null   int64
# dtypes: category(1), int64(1), object(1)
# memory usage: 90.1+ KB

# %%
train_provider.shape
# Out:
# (5410, 3)

# %%
rows, cols = train_provider.shape
print(f"Liczba wierszy: {rows}")
print(f"Liczba kolumn: {cols}")
# Out:
# Liczba wierszy: 5410
# Liczba kolumn: 3

# %%
# Wczytanie danych z beneficiary
train_beneficiary = pd.read_csv('Train_Beneficiarydata-1542865627584.csv')

# sprawdzenie head
train_beneficiary.head()
# Out:
#       BeneID         DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001  1943-01-01  NaN       1     1                     0     39
# 1  BENE11002  1936-09-01  NaN       2     1                     0     39
# 2  BENE11003  1936-08-01  NaN       1     1                     0     52
# 3  BENE11004  1922-07-01  NaN       1     1                     0     39
# 4  BENE11005  1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
# 3                         1                          2                   2
# 4                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
# 3                           2                       2                     1
# 4                           1                       2                     1
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
# 3                          1                         1
# 4                          2                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
# 3                                1                   2
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
# 3                         0                      0                      1810
# 4                         0                      0                      1790
#
#    OPAnnualDeductibleAmt
# 0                     70
# 1                     50
# 2                     40
# 3                    760
# 4                   1200

# %%
train_beneficiary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  object
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
#  11  ChronicCond_Heartfailure         138556 non-null  int64
#  12  ChronicCond_KidneyDisease        138556 non-null  int64
#  13  ChronicCond_Cancer               138556 non-null  int64
#  14  ChronicCond_ObstrPulmonary       138556 non-null  int64
#  15  ChronicCond_Depression           138556 non-null  int64
#  16  ChronicCond_Diabetes             138556 non-null  int64
#  17  ChronicCond_IschemicHeart        138556 non-null  int64
#  18  ChronicCond_Osteoporasis         138556 non-null  int64
#  19  ChronicCond_rheumatoidarthritis  138556 non-null  int64
#  20  ChronicCond_stroke               138556 non-null  int64
#  21  IPAnnualReimbursementAmt         138556 non-null  int64
#  22  IPAnnualDeductibleAmt            138556 non-null  int64
#  23  OPAnnualReimbursementAmt         138556 non-null  int64
#  24  OPAnnualDeductibleAmt            138556 non-null  int64
# dtypes: int64(21), object(4)
# memory usage: 26.4+ MB

# %%
#DOB i DOD powinny być datetime

# %%
train_beneficiary.shape
# Out:
# (138556, 25)

# %%
train_beneficiary['RenalDiseaseIndicator'].value_counts()
# Out:
# RenalDiseaseIndicator
# 0    118978
# Y     19578
# Name: count, dtype: int64

# %%
#renalDiseaseIndicator albo nie mamy danych wtedy 0 albo jest ktoś chory

# %% [markdown]
# Ile osób  > 65 ma renalDiseaseIdicator

# %%
#Ile osób  > 65 ma renalDiseaseIndicator na true

# Zamiana DOB na datetime
train_beneficiary['DOB'] = pd.to_datetime(train_beneficiary['DOB'], errors='coerce')

# Data odniesienia: koniec 2009 roku
reference_date = pd.to_datetime('2009-12-31')

# Obliczenie wieku
train_beneficiary['Age'] = ((reference_date - train_beneficiary['DOB']).dt.days // 365)

# 🧮 Licznik: osoby > 65 z chorobą nerek
renal_over_65 = train_beneficiary[
    (train_beneficiary['Age'] > 65) &
    (train_beneficiary['RenalDiseaseIndicator'] == 'Y')
]

# 🧮 Mianownik: wszystkie osoby > 65 lat
over_65 = train_beneficiary[train_beneficiary['Age'] > 65]

# ✅ Wyniki
print("Liczba osób >65 z chorobą nerek:", len(renal_over_65))
print("Liczba wszystkich osób >65:", len(over_65))

# 🔢 Procent:
percent = len(renal_over_65) / len(over_65) * 100
print(f"Procent osób > 65 z chorobą nerek: {percent:.2f}%")
# Out:
# Liczba osób >65 z chorobą nerek: 16219
# Liczba wszystkich osób >65: 115881
# Procent osób > 65 z chorobą nerek: 14.00%

# %%
#Ile osób poniżej < 65 ma renalDisease

# 🧮 Licznik: osoby < 65 z chorobą nerek
renal_under_65 = train_beneficiary[
    (train_beneficiary['Age'] < 65) &
    (train_beneficiary['RenalDiseaseIndicator'] == 'Y')
]

# 🧮 Mianownik: wszystkie osoby < 65 lat
under_65 = train_beneficiary[train_beneficiary['Age'] < 65]

# ✅ Wyniki
print("Liczba osób < 65 z chorobą nerek:", len(renal_under_65))
print("Liczba wszystkich osób < 65:", len(under_65))

# 🔢 Procent:
percent_under = len(renal_under_65) / len(under_65) * 100
print(f"Procent osób < 65 z chorobą nerek: {percent_under:.2f}%")
# Out:
# Liczba osób < 65 z chorobą nerek: 3199
# Liczba wszystkich osób < 65: 21607
# Procent osób < 65 z chorobą nerek: 14.81%

# %%
#Czyli ok 14% ma wszystkich objetych ubezpieczeniem renalDisease

# %%
#Ile tych co ma renal disease ma chronicKidney

# Filtrowanie: osoby z chorobą nerek i z chroniczną chorobą nerek
renal_and_ckd = train_beneficiary[
    (train_beneficiary['RenalDiseaseIndicator'] == 'Y') &
    (train_beneficiary['ChronicCond_KidneyDisease'] == 1)
]

# Liczba osób z obiema cechami
print("Liczba osób z RenalDiseaseIndicator == 'Y' i ChronicKidney == 1:", len(renal_and_ckd))

# Wszystkie osoby z RenalDiseaseIndicator == 'Y'
renal_all = train_beneficiary[train_beneficiary['RenalDiseaseIndicator'] == 'Y']

# Procent tych, którzy mają również chronic kidney disease
percent_ckd = len(renal_and_ckd) / len(renal_all) * 100

print(f"Procent osób z chorobą nerek, które mają też chronic kidney disease: {percent_ckd:.2f}%")
# Out:
# Liczba osób z RenalDiseaseIndicator == 'Y' i ChronicKidney == 1: 15511
# Procent osób z chorobą nerek, które mają też chronic kidney disease: 79.23%

# %%
# 79% tylko więc nie możemy zastąpić jedna kolumnę drugą chociaż widać zależności

# %%
train_beneficiary.head()
# Out:
#       BeneID        DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001 1943-01-01  NaN       1     1                     0     39
# 1  BENE11002 1936-09-01  NaN       2     1                     0     39
# 2  BENE11003 1936-08-01  NaN       1     1                     0     52
# 3  BENE11004 1922-07-01  NaN       1     1                     0     39
# 4  BENE11005 1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
# 3                         1                          2                   2
# 4                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
# 3                           2                       2                     1
# 4                           1                       2                     1
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
# 3                          1                         1
# 4                          2                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
# 3                                1                   2
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
# 3                         0                      0                      1810
# 4                         0                      0                      1790
#
#    OPAnnualDeductibleAmt  Age
# 0                     70   67
# 1                     50   73
# 2                     40   73
# 3                    760   87
# 4                   1200   74

# %%
# Jakie są wartości w NoOfMonths_PartACov

train_beneficiary['NoOfMonths_PartACov'].value_counts(normalize=True) * 100
# Out:
# NoOfMonths_PartACov
# 12    99.157741
# 0      0.721730
# 6      0.027426
# 11     0.020208
# 8      0.018765
# 10     0.012991
# 7      0.011548
# 4      0.009382
# 5      0.005774
# 9      0.005052
# 3      0.003609
# 2      0.003609
# 1      0.002165
# Name: proportion, dtype: float64

# %%
# Jakie są wartości w NoOfMonths_PartACov

train_beneficiary['NoOfMonths_PartBCov'].value_counts(normalize=True) * 100
# Out:
# NoOfMonths_PartBCov
# 12    98.806259
# 0      0.487168
# 6      0.203528
# 10     0.108259
# 11     0.103207
# 9      0.088051
# 8      0.051243
# 7      0.045469
# 5      0.036086
# 4      0.025261
# 3      0.019487
# 2      0.013713
# 1      0.012269
# Name: proportion, dtype: float64

# %%
train_beneficiary.head()
# Out:
#       BeneID        DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001 1943-01-01  NaN       1     1                     0     39
# 1  BENE11002 1936-09-01  NaN       2     1                     0     39
# 2  BENE11003 1936-08-01  NaN       1     1                     0     52
# 3  BENE11004 1922-07-01  NaN       1     1                     0     39
# 4  BENE11005 1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
# 3                         1                          2                   2
# 4                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
# 3                           2                       2                     1
# 4                           1                       2                     1
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
# 3                          1                         1
# 4                          2                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
# 3                                1                   2
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
# 3                         0                      0                      1810
# 4                         0                      0                      1790
#
#    OPAnnualDeductibleAmt  Age
# 0                     70   67
# 1                     50   73
# 2                     40   73
# 3                    760   87
# 4                   1200   74

# %%
train_beneficiary['ChronicCond_Cancer'].value_counts()
# Out:
# ChronicCond_Cancer
# 2    121935
# 1     16621
# Name: count, dtype: int64

# %%
#Ile procent benficjantów ma daną chorobę np alzehemiera

# Lista kolumn z chorobami przewlekłymi
chronic_cols = [
    'ChronicCond_Alzheimer',
    'ChronicCond_Heartfailure',
    'ChronicCond_Cancer',
    'ChronicCond_Diabetes',
    'ChronicCond_KidneyDisease',
    'ChronicCond_Depression',
    'ChronicCond_stroke',
    'ChronicCond_ObstrPulmonary',
    'ChronicCond_IschemicHeart',
    'ChronicCond_Osteoporasis',
    'ChronicCond_rheumatoidarthritis',
]

results = {}

for col in chronic_cols:
    # Uwzględniamy tylko wiersze, gdzie nie ma wartości brakujących (czyli != 2)
    valid = train_beneficiary[train_beneficiary[col] != 2]
    
    # Liczymy procent osób z daną chorobą
    percent = (len(valid)/len(train_beneficiary)) * 100
    
    results[col] = percent

# Zamiana na DataFrame dla czytelniejszego podsumowania
df_results = pd.DataFrame.from_dict(results, orient='index', columns=['Procent osób z chorobą'])
df_results = df_results.sort_values(by='Procent osób z chorobą', ascending=False)

print(df_results)
# Out:
#                                  Procent osób z chorobą
# ChronicCond_IschemicHeart                     67.585669
# ChronicCond_Diabetes                          60.185773
# ChronicCond_Heartfailure                      49.367765
# ChronicCond_Depression                        35.552412
# ChronicCond_Alzheimer                         33.218338
# ChronicCond_KidneyDisease                     31.235746
# ChronicCond_Osteoporasis                      27.468316
# ChronicCond_rheumatoidarthritis               25.682035
# ChronicCond_ObstrPulmonary                    23.715321
# ChronicCond_Cancer                            11.995872
# ChronicCond_stroke                             7.905829

# %%
#Ile procent benficjantów > 65 lat ma daną chorobę np alzehemiera

# Lista kolumn z chorobami przewlekłymi
chronic_cols = [
    'ChronicCond_Alzheimer',
    'ChronicCond_Heartfailure',
    'ChronicCond_Cancer',
    'ChronicCond_Diabetes',
    'ChronicCond_KidneyDisease',
    'ChronicCond_Depression',
    'ChronicCond_stroke',
    'ChronicCond_ObstrPulmonary',
    'ChronicCond_IschemicHeart',
    'ChronicCond_Osteoporasis',
    'ChronicCond_rheumatoidarthritis',
]

results = {}

older = train_beneficiary[train_beneficiary['Age'] > 65]
for col in chronic_cols:
    # Uwzględniamy tylko wiersze, gdzie nie ma wartości brakujących (czyli != 2)
    valid = older[older[col] != 2]
    
    # Liczymy procent osób z daną chorobą
    percent = (len(valid)/len(older)) * 100
    
    results[col] = percent

# Zamiana na DataFrame dla czytelniejszego podsumowania
df_results = pd.DataFrame.from_dict(results, orient='index', columns=['Procent osób z chorobą wśród osób starszych >65'])
df_results = df_results.sort_values(by='Procent osób z chorobą wśród osób starszych >65', ascending=False)

print(df_results)
# Out:
#                                  Procent osób z chorobą wśród osób starszych >65
# ChronicCond_IschemicHeart                                              67.877391
# ChronicCond_Diabetes                                                   60.286846
# ChronicCond_Heartfailure                                               49.454181
# ChronicCond_Depression                                                 34.514718
# ChronicCond_Alzheimer                                                  33.014903
# ChronicCond_KidneyDisease                                              31.144018
# ChronicCond_Osteoporasis                                               27.734486
# ChronicCond_rheumatoidarthritis                                        25.911927
# ChronicCond_ObstrPulmonary                                             23.562965
# ChronicCond_Cancer                                                     12.327301
# ChronicCond_stroke                                                      7.950397

# %%
#Ile procent benficjantów <=65 ma daną chorobę np alzehemiera

# Lista kolumn z chorobami przewlekłymi
chronic_cols = [
    'ChronicCond_Alzheimer',
    'ChronicCond_Heartfailure',
    'ChronicCond_Cancer',
    'ChronicCond_Diabetes',
    'ChronicCond_KidneyDisease',
    'ChronicCond_Depression',
    'ChronicCond_stroke',
    'ChronicCond_ObstrPulmonary',
    'ChronicCond_IschemicHeart',
    'ChronicCond_Osteoporasis',
    'ChronicCond_rheumatoidarthritis',
]

results = {}

younger = train_beneficiary[train_beneficiary['Age'] <= 65]
younger_count = len(younger)
older = train_beneficiary[train_beneficiary['Age'] > 65]
older_count = len(older)
print(younger_count, older_count, len(train_beneficiary), older_count+younger_count)

results = {}

for col in chronic_cols:
    # Uwzględniamy tylko wiersze, gdzie nie ma wartości brakujących (czyli != 2)
    valid = younger[younger[col] != 2]
    
    # Liczymy procent osób z daną chorobą
    percent = (len(valid)/len(younger))*100
    
    results[col] = percent


# Zamiana na DataFrame dla czytelniejszego podsumowania
df_results = pd.DataFrame.from_dict(results, orient='index', columns=['Procent osób z chorobą wśród osób starszych <65'])
df_results = df_results.sort_values(by='Procent osób z chorobą wśród osób starszych <65', ascending=False)

print(df_results)
# Out:
# 22675 115881 138556 138556
#                                  Procent osób z chorobą wśród osób starszych <65
# ChronicCond_IschemicHeart                                              66.094818
# ChronicCond_Diabetes                                                   59.669239
# ChronicCond_Heartfailure                                               48.926130
# ChronicCond_Depression                                                 40.855568
# ChronicCond_Alzheimer                                                  34.257993
# ChronicCond_KidneyDisease                                              31.704520
# ChronicCond_Osteoporasis                                               26.108049
# ChronicCond_rheumatoidarthritis                                        24.507166
# ChronicCond_ObstrPulmonary                                             24.493936
# ChronicCond_Cancer                                                     10.302095
# ChronicCond_stroke                                                      7.678060

# %%
train_beneficiary.head()
# Out:
#       BeneID        DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001 1943-01-01  NaN       1     1                     0     39
# 1  BENE11002 1936-09-01  NaN       2     1                     0     39
# 2  BENE11003 1936-08-01  NaN       1     1                     0     52
# 3  BENE11004 1922-07-01  NaN       1     1                     0     39
# 4  BENE11005 1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
# 3                         1                          2                   2
# 4                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
# 3                           2                       2                     1
# 4                           1                       2                     1
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
# 3                          1                         1
# 4                          2                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
# 3                                1                   2
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
# 3                         0                      0                      1810
# 4                         0                      0                      1790
#
#    OPAnnualDeductibleAmt  Age
# 0                     70   67
# 1                     50   73
# 2                     40   73
# 3                    760   87
# 4                   1200   74

# %%
train_beneficiary['IPAnnualReimbursementAmt'].value_counts(normalize=True) * 100
# Out:
# IPAnnualReimbursementAmt
# 0        73.985248
# 4000      1.532232
# 5000      1.335922
# 3000      1.299114
# 6000      1.146829
#            ...
# 8630      0.000722
# 58350     0.000722
# 52600     0.000722
# 17190     0.000722
# 6170      0.000722
# Name: proportion, Length: 3004, dtype: float64

# %%
# To pokazuje że w 73%  Medicare za leczenie szpitalne w ciągu roku 0

# %% [markdown]
# Który state i county najczestszy fraud
# Jakie choroby się najcześciej razem pojawiają
# Jakie choroby pojawiają się najczesciej przy fraudzie

# %%
#Patrzymy na statystyki wypłat za leczenie szpitalne ale biorąc pod uwagę tylko tych którzy byli w szpitalu
ip_annual_reimb_over_0 = train_beneficiary[train_beneficiary['IPAnnualReimbursementAmt']>0]
ip_annual_reimb_over_0['IPAnnualReimbursementAmt'].describe()
# Out:
# count     36030.000000
# mean      14076.496253
# std       14334.295941
# min          10.000000
# 25%        5000.000000
# 50%        9505.000000
# 75%       17000.000000
# max      161470.000000
# Name: IPAnnualReimbursementAmt, dtype: float64

# %%
train_beneficiary['IPAnnualReimbursementAmt'].describe()
# Out:
# count    138556.000000
# mean       3660.346502
# std        9568.621827
# min       -8000.000000
# 25%           0.000000
# 50%           0.000000
# 75%        2280.000000
# max      161470.000000
# Name: IPAnnualReimbursementAmt, dtype: float64

# %%
# tutaj widać jakby były uwzglednieni pacjenci co 0 otrzymali - widać jak bardzo są zaburzone

# %%
# IPAnnualDeductibleAmt
# = Roczna kwota udziału własnego pacjenta (deductible) za leczenie szpitalne (Inpatient)

# %%
train_beneficiary['IPAnnualDeductibleAmt'].value_counts(normalize=True) * 100
# Out:
# IPAnnualDeductibleAmt
# 0        73.630157
# 1068     19.568261
# 2136      4.632062
# 3204      1.068882
# 4272      0.266318
#            ...
# 3234      0.000722
# 1118      0.000722
# 3904      0.000722
# 21204     0.000722
# 24068     0.000722
# Name: proportion, Length: 147, dtype: float64

# %%
#Patrzymy na statystyki wypłat za leczenie szpitalne ale biorąc pod uwagę tylko tych którzy byli w szpitalu
ip_annual_deduct_over_0 = train_beneficiary[train_beneficiary['IPAnnualDeductibleAmt']>0]
ip_annual_deduct_over_0['IPAnnualDeductibleAmt'].describe()
# Out:
# count    36537.000000
# mean      1516.305170
# std       1332.006369
# min       1068.000000
# 25%       1068.000000
# 50%       1068.000000
# 75%       2136.000000
# max      38272.000000
# Name: IPAnnualDeductibleAmt, dtype: float64

# %%
train_beneficiary['OPAnnualDeductibleAmt'].value_counts(normalize=True) * 100
# Out:
# OPAnnualDeductibleAmt
# 0        10.024828
# 20        5.247698
# 10        4.431421
# 30        3.431825
# 100       3.423165
#            ...
# 6610      0.000722
# 4090      0.000722
# 7930      0.000722
# 4320      0.000722
# 13040     0.000722
# Name: proportion, Length: 789, dtype: float64

# %%
#Patrzymy na statystyki wypłat za leczenie ambulatoryjene ale biorąc pod uwagę tylko tych którzy wygenerowali koszty
opa_annual_deduct_over_0 = train_beneficiary[train_beneficiary['OPAnnualDeductibleAmt']>0]
opa_annual_deduct_over_0['OPAnnualDeductibleAmt'].describe()
# Out:
# count    124666.000000
# mean        419.802761
# std         667.436176
# min          10.000000
# 25%          70.000000
# 50%         200.000000
# 75%         510.000000
# max       13840.000000
# Name: OPAnnualDeductibleAmt, dtype: float64

# %%
train_beneficiary['OPAnnualReimbursementAmt'].value_counts(normalize=True) * 100
# Out:
# OPAnnualReimbursementAmt
# 0        3.034874
# 100      2.826294
# 200      2.275614
# 60       1.944340
# 300      1.645544
#            ...
# 12130    0.000722
# 22470    0.000722
# 16030    0.000722
# 19390    0.000722
# 38650    0.000722
# Name: proportion, Length: 2078, dtype: float64

# %%
#tutaj już tylko 3% nie korzysta z uslug ambulatoryjnych

# %%
#Patrzymy na statystyki wypłat za leczenie ambulatoryjene ale biorąc pod uwagę tylko tych którzy wygenerowali koszty
opa_annual_deduct_over_0 = train_beneficiary[train_beneficiary['OPAnnualReimbursementAmt']>0]
opa_annual_deduct_over_0['OPAnnualReimbursementAmt'].describe()
# Out:
# count    134339.000000
# mean       1338.974832
# std        2521.944636
# min          10.000000
# 25%         200.000000
# 50%         600.000000
# 75%        1560.000000
# max      102960.000000
# Name: OPAnnualReimbursementAmt, dtype: float64

# %%
# Duzy rozdzwięk między min a max i pomiedzy średnią a 50%

# %%
# Wczytanie danych z beneficiary
train_inpatientdata = pd.read_csv('Train_Inpatientdata-1542865627584.csv')


# sprawdzenie head
train_inpatientdata.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
train_inpatientdata.shape
# Out:
# (40474, 30)

# %%
train_inpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
#  13  DiagnosisGroupCode      40474 non-null  object
#  14  ClmDiagnosisCode_1      40474 non-null  object
#  15  ClmDiagnosisCode_2      40248 non-null  object
#  16  ClmDiagnosisCode_3      39798 non-null  object
#  17  ClmDiagnosisCode_4      38940 non-null  object
#  18  ClmDiagnosisCode_5      37580 non-null  object
#  19  ClmDiagnosisCode_6      35636 non-null  object
#  20  ClmDiagnosisCode_7      33216 non-null  object
#  21  ClmDiagnosisCode_8      30532 non-null  object
#  22  ClmDiagnosisCode_9      26977 non-null  object
#  23  ClmDiagnosisCode_10     3927 non-null   object
#  24  ClmProcedureCode_1      23148 non-null  float64
#  25  ClmProcedureCode_2      5454 non-null   float64
#  26  ClmProcedureCode_3      965 non-null    float64
#  27  ClmProcedureCode_4      116 non-null    float64
#  28  ClmProcedureCode_5      9 non-null      float64
#  29  ClmProcedureCode_6      0 non-null      float64
# dtypes: float64(7), int64(1), object(22)
# memory usage: 9.3+ MB

# %%
# widać że wszystkie daty  ClaimStartDt ClaimEndDt  AdmissionDt są object a nie daty

# %%
# Wczytanie danych z beneficiary
train_outpatientdata = pd.read_csv('Train_Outpatientdata-1542865627584.csv')


# sprawdzenie head
train_outpatientdata.head()
# Out:
#       BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11002  CLM624349   2009-10-11  2009-10-11  PRV56011
# 1  BENE11003  CLM189947   2009-02-12  2009-02-12  PRV57610
# 2  BENE11003  CLM438021   2009-06-27  2009-06-27  PRV57595
# 3  BENE11004  CLM121801   2009-01-06  2009-01-06  PRV56011
# 4  BENE11004  CLM150998   2009-01-22  2009-01-22  PRV56011
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                      30          PHY326117                NaN
# 1                      80          PHY362868                NaN
# 2                      10          PHY328821                NaN
# 3                      40          PHY334319                NaN
# 4                     200          PHY403831                NaN
#
#   OtherPhysician ClmDiagnosisCode_1 ClmDiagnosisCode_2 ClmDiagnosisCode_3  \
# 0            NaN              78943              V5866              V1272
# 1            NaN               6115                NaN                NaN
# 2            NaN               2723                NaN                NaN
# 3            NaN              71988                NaN                NaN
# 4            NaN              82382              30000              72887
#
#   ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6 ClmDiagnosisCode_7  \
# 0                NaN                NaN                NaN                NaN
# 1                NaN                NaN                NaN                NaN
# 2                NaN                NaN                NaN                NaN
# 3                NaN                NaN                NaN                NaN
# 4               4280               7197              V4577                NaN
#
#   ClmDiagnosisCode_8 ClmDiagnosisCode_9 ClmDiagnosisCode_10  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#    ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    DeductibleAmtPaid ClmAdmitDiagnosisCode
# 0                  0                 56409
# 1                  0                 79380
# 2                  0                   NaN
# 3                  0                   NaN
# 4                  0                 71947

# %%
train_outpatientdata.shape
# Out:
# (517737, 27)

# %%
train_outpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  object
#  3   ClaimEndDt              517737 non-null  object
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
#  14  ClmDiagnosisCode_6      48756 non-null   object
#  15  ClmDiagnosisCode_7      32961 non-null   object
#  16  ClmDiagnosisCode_8      22912 non-null   object
#  17  ClmDiagnosisCode_9      14838 non-null   object
#  18  ClmDiagnosisCode_10     1083 non-null    object
#  19  ClmProcedureCode_1      162 non-null     float64
#  20  ClmProcedureCode_2      36 non-null      float64
#  21  ClmProcedureCode_3      4 non-null       float64
#  22  ClmProcedureCode_4      2 non-null       float64
#  23  ClmProcedureCode_5      0 non-null       float64
#  24  ClmProcedureCode_6      0 non-null       float64
#  25  DeductibleAmtPaid       517737 non-null  int64
#  26  ClmAdmitDiagnosisCode   105425 non-null  object
# dtypes: float64(6), int64(2), object(19)
# memory usage: 106.7+ MB

# %%
# znowu widać że wszystkie daty  ClaimStartDt ClaimEndDt  AdmissionDt są object a nie daty

# %%
# Czy w zbiorze występują brakujące wartości (NaN, null)?

train_provider.info()
train_beneficiary.info()
train_inpatientdata.info()
train_outpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   category
#  2   FraudFlag       5410 non-null   int64
# dtypes: category(1), int64(1), object(1)
# memory usage: 90.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138556 entries, 0 to 138555
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           138556 non-null  object
#  1   DOB                              138556 non-null  datetime64[ns]
#  2   DOD                              1421 non-null    object
#  3   Gender                           138556 non-null  int64
#  4   Race                             138556 non-null  int64
#  5   RenalDiseaseIndicator            138556 non-null  object
#  6   State                            138556 non-null  int64
#  7   County                           138556 non-null  int64
#  8   NoOfMonths_PartACov              138556 non-null  int64
#  9   NoOfMonths_PartBCov              138556 non-null  int64
#  10  ChronicCond_Alzheimer            138556 non-null  int64
#  11  ChronicCond_Heartfailure         138556 non-null  int64
#  12  ChronicCond_KidneyDisease        138556 non-null  int64
#  13  ChronicCond_Cancer               138556 non-null  int64
#  14  ChronicCond_ObstrPulmonary       138556 non-null  int64
#  15  ChronicCond_Depression           138556 non-null  int64
#  16  ChronicCond_Diabetes             138556 non-null  int64
#  17  ChronicCond_IschemicHeart        138556 non-null  int64
#  18  ChronicCond_Osteoporasis         138556 non-null  int64
#  19  ChronicCond_rheumatoidarthritis  138556 non-null  int64
#  20  ChronicCond_stroke               138556 non-null  int64
#  21  IPAnnualReimbursementAmt         138556 non-null  int64
#  22  IPAnnualDeductibleAmt            138556 non-null  int64
#  23  OPAnnualReimbursementAmt         138556 non-null  int64
#  24  OPAnnualDeductibleAmt            138556 non-null  int64
#  25  Age                              138556 non-null  int64
# dtypes: datetime64[ns](1), int64(22), object(3)
# memory usage: 27.5+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  object
#  3   ClaimEndDt              40474 non-null  object
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  object
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  object
#  13  DiagnosisGroupCode      40474 non-null  object
#  14  ClmDiagnosisCode_1      40474 non-null  object
#  15  ClmDiagnosisCode_2      40248 non-null  object
#  16  ClmDiagnosisCode_3      39798 non-null  object
#  17  ClmDiagnosisCode_4      38940 non-null  object
#  18  ClmDiagnosisCode_5      37580 non-null  object
#  19  ClmDiagnosisCode_6      35636 non-null  object
#  20  ClmDiagnosisCode_7      33216 non-null  object
#  21  ClmDiagnosisCode_8      30532 non-null  object
#  22  ClmDiagnosisCode_9      26977 non-null  object
#  23  ClmDiagnosisCode_10     3927 non-null   object
#  24  ClmProcedureCode_1      23148 non-null  float64
#  25  ClmProcedureCode_2      5454 non-null   float64
#  26  ClmProcedureCode_3      965 non-null    float64
#  27  ClmProcedureCode_4      116 non-null    float64
#  28  ClmProcedureCode_5      9 non-null      float64
#  29  ClmProcedureCode_6      0 non-null      float64
# dtypes: float64(7), int64(1), object(22)
# memory usage: 9.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517737 entries, 0 to 517736
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   BeneID                  517737 non-null  object
#  1   ClaimID                 517737 non-null  object
#  2   ClaimStartDt            517737 non-null  object
#  3   ClaimEndDt              517737 non-null  object
#  4   Provider                517737 non-null  object
#  5   InscClaimAmtReimbursed  517737 non-null  int64
#  6   AttendingPhysician      516341 non-null  object
#  7   OperatingPhysician      90617 non-null   object
#  8   OtherPhysician          195046 non-null  object
#  9   ClmDiagnosisCode_1      507284 non-null  object
#  10  ClmDiagnosisCode_2      322357 non-null  object
#  11  ClmDiagnosisCode_3      203257 non-null  object
#  12  ClmDiagnosisCode_4      125596 non-null  object
#  13  ClmDiagnosisCode_5      74344 non-null   object
#  14  ClmDiagnosisCode_6      48756 non-null   object
#  15  ClmDiagnosisCode_7      32961 non-null   object
#  16  ClmDiagnosisCode_8      22912 non-null   object
#  17  ClmDiagnosisCode_9      14838 non-null   object
#  18  ClmDiagnosisCode_10     1083 non-null    object
#  19  ClmProcedureCode_1      162 non-null     float64
#  20  ClmProcedureCode_2      36 non-null      float64
#  21  ClmProcedureCode_3      4 non-null       float64
#  22  ClmProcedureCode_4      2 non-null       float64
#  23  ClmProcedureCode_5      0 non-null       float64
#  24  ClmProcedureCode_6      0 non-null       float64
#  25  DeductibleAmtPaid       517737 non-null  int64
#  26  ClmAdmitDiagnosisCode   105425 non-null  object
# dtypes: float64(6), int64(2), object(19)
# memory usage: 106.7+ MB

# %%
#Wszystkie kolumny są oznaczone jako not-null, ale jak wynika z analizy u góry, niektóre z kolumn skrywają duzo danych brakujących lub NAN
# Sprawdzenie brakujących danych dla train_provider
print("Braki w train_provider:")
print(train_provider.isnull().sum())
print("\n")

# Sprawdzenie brakujących danych dla train_beneficiary
print("Braki w train_beneficiary:")
print(train_beneficiary.isnull().sum())
print("\n")

# Sprawdzenie brakujących danych dla train_inpatientdata
print("Braki w train_inpatientdata:")
print(train_inpatientdata.isnull().sum())
print("\n")

# Sprawdzenie brakujących danych dla train_outpatientdata
print("Braki w train_outpatientdata:")
print(train_outpatientdata.isnull().sum())
print("\n")
# Out:
# Braki w train_provider:
# Provider          0
# PotentialFraud    0
# FraudFlag         0
# dtype: int64
#
#
# Braki w train_beneficiary:
# BeneID                                  0
# DOB                                     0
# DOD                                137135
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# Age                                     0
# dtype: int64
#
#
# Braki w train_inpatientdata:
# BeneID                        0
# ClaimID                       0
# ClaimStartDt                  0
# ClaimEndDt                    0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# AdmissionDt                   0
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid           899
# DischargeDt                   0
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1        17326
# ClmProcedureCode_2        35020
# ClmProcedureCode_3        39509
# ClmProcedureCode_4        40358
# ClmProcedureCode_5        40465
# ClmProcedureCode_6        40474
# dtype: int64
#
#
# Braki w train_outpatientdata:
# BeneID                         0
# ClaimID                        0
# ClaimStartDt                   0
# ClaimEndDt                     0
# Provider                       0
# InscClaimAmtReimbursed         0
# AttendingPhysician          1396
# OperatingPhysician        427120
# OtherPhysician            322691
# ClmDiagnosisCode_1         10453
# ClmDiagnosisCode_2        195380
# ClmDiagnosisCode_3        314480
# ClmDiagnosisCode_4        392141
# ClmDiagnosisCode_5        443393
# ClmDiagnosisCode_6        468981
# ClmDiagnosisCode_7        484776
# ClmDiagnosisCode_8        494825
# ClmDiagnosisCode_9        502899
# ClmDiagnosisCode_10       516654
# ClmProcedureCode_1        517575
# ClmProcedureCode_2        517701
# ClmProcedureCode_3        517733
# ClmProcedureCode_4        517735
# ClmProcedureCode_5        517737
# ClmProcedureCode_6        517737
# DeductibleAmtPaid              0
# ClmAdmitDiagnosisCode     412312
# dtype: int64

# %%
train_beneficiary.head()
# Out:
#       BeneID        DOB  DOD  Gender  Race RenalDiseaseIndicator  State  \
# 0  BENE11001 1943-01-01  NaN       1     1                     0     39
# 1  BENE11002 1936-09-01  NaN       2     1                     0     39
# 2  BENE11003 1936-08-01  NaN       1     1                     0     52
# 3  BENE11004 1922-07-01  NaN       1     1                     0     39
# 4  BENE11005 1935-09-01  NaN       1     1                     0     24
#
#    County  NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0     230                   12                   12                      1
# 1     280                   12                   12                      2
# 2     590                   12                   12                      1
# 3     270                   12                   12                      1
# 4     680                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          2                   2
# 2                         2                          2                   2
# 3                         1                          2                   2
# 4                         2                          2                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       2                     2
# 2                           2                       2                     2
# 3                           2                       2                     1
# 4                           1                       2                     1
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          2                         2
# 2                          1                         2
# 3                          1                         1
# 4                          2                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                2                   2
# 2                                2                   2
# 3                                1                   2
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                         0                      0                        30
# 2                         0                      0                        90
# 3                         0                      0                      1810
# 4                         0                      0                      1790
#
#    OPAnnualDeductibleAmt  Age
# 0                     70   67
# 1                     50   73
# 2                     40   73
# 3                    760   87
# 4                   1200   74

# %%
# W train_beneficiary jest tylko DOD date of death z NaN która mowi że nie ma wartości i jest to wiadomość że pacjent nie zmarl 
# ChronicCond_Alzheimer.... i wszystkie inne maja 2 dla oznaczenia że nie ma wartoci ktora tak naprawde jest NaN

# %%
train_inpatientdata.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
# Sprawdzenie brakujących danych dla train_inpatientdata
print("Braki w train_inpatientdata:")
print(train_inpatientdata.isnull().sum())
print("\n")
# Out:
# Braki w train_inpatientdata:
# BeneID                        0
# ClaimID                       0
# ClaimStartDt                  0
# ClaimEndDt                    0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# AdmissionDt                   0
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid           899
# DischargeDt                   0
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1        17326
# ClmProcedureCode_2        35020
# ClmProcedureCode_3        39509
# ClmProcedureCode_4        40358
# ClmProcedureCode_5        40465
# ClmProcedureCode_6        40474
# dtype: int64

# %%
train_inpatientdata['AdmissionDt'] = pd.to_datetime(train_inpatientdata['AdmissionDt'], errors='coerce')
train_inpatientdata['DischargeDt'] = pd.to_datetime(train_inpatientdata['DischargeDt'], errors='coerce')
train_inpatientdata['ClaimStartDt'] = pd.to_datetime(train_inpatientdata['ClaimStartDt'], errors='coerce')
train_inpatientdata['ClaimEndDt'] = pd.to_datetime(train_inpatientdata['ClaimEndDt'], errors='coerce')

train_inpatientdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40474 entries, 0 to 40473
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   BeneID                  40474 non-null  object
#  1   ClaimID                 40474 non-null  object
#  2   ClaimStartDt            40474 non-null  datetime64[ns]
#  3   ClaimEndDt              40474 non-null  datetime64[ns]
#  4   Provider                40474 non-null  object
#  5   InscClaimAmtReimbursed  40474 non-null  int64
#  6   AttendingPhysician      40362 non-null  object
#  7   OperatingPhysician      23830 non-null  object
#  8   OtherPhysician          4690 non-null   object
#  9   AdmissionDt             40474 non-null  datetime64[ns]
#  10  ClmAdmitDiagnosisCode   40474 non-null  object
#  11  DeductibleAmtPaid       39575 non-null  float64
#  12  DischargeDt             40474 non-null  datetime64[ns]
#  13  DiagnosisGroupCode      40474 non-null  object
#  14  ClmDiagnosisCode_1      40474 non-null  object
#  15  ClmDiagnosisCode_2      40248 non-null  object
#  16  ClmDiagnosisCode_3      39798 non-null  object
#  17  ClmDiagnosisCode_4      38940 non-null  object
#  18  ClmDiagnosisCode_5      37580 non-null  object
#  19  ClmDiagnosisCode_6      35636 non-null  object
#  20  ClmDiagnosisCode_7      33216 non-null  object
#  21  ClmDiagnosisCode_8      30532 non-null  object
#  22  ClmDiagnosisCode_9      26977 non-null  object
#  23  ClmDiagnosisCode_10     3927 non-null   object
#  24  ClmProcedureCode_1      23148 non-null  float64
#  25  ClmProcedureCode_2      5454 non-null   float64
#  26  ClmProcedureCode_3      965 non-null    float64
#  27  ClmProcedureCode_4      116 non-null    float64
#  28  ClmProcedureCode_5      9 non-null      float64
#  29  ClmProcedureCode_6      0 non-null      float64
# dtypes: datetime64[ns](4), float64(7), int64(1), object(18)
# memory usage: 9.3+ MB

# %%
# Sprawdzenie brakujących danych dla train_inpatientdata
print("Braki w train_inpatientdata:")
print(train_inpatientdata.isnull().sum())
# Out:
# Braki w train_inpatientdata:
# BeneID                        0
# ClaimID                       0
# ClaimStartDt                  0
# ClaimEndDt                    0
# Provider                      0
# InscClaimAmtReimbursed        0
# AttendingPhysician          112
# OperatingPhysician        16644
# OtherPhysician            35784
# AdmissionDt                   0
# ClmAdmitDiagnosisCode         0
# DeductibleAmtPaid           899
# DischargeDt                   0
# DiagnosisGroupCode            0
# ClmDiagnosisCode_1            0
# ClmDiagnosisCode_2          226
# ClmDiagnosisCode_3          676
# ClmDiagnosisCode_4         1534
# ClmDiagnosisCode_5         2894
# ClmDiagnosisCode_6         4838
# ClmDiagnosisCode_7         7258
# ClmDiagnosisCode_8         9942
# ClmDiagnosisCode_9        13497
# ClmDiagnosisCode_10       36547
# ClmProcedureCode_1        17326
# ClmProcedureCode_2        35020
# ClmProcedureCode_3        39509
# ClmProcedureCode_4        40358
# ClmProcedureCode_5        40465
# ClmProcedureCode_6        40474
# dtype: int64

# %%
train_inpatientdata.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
train_inpatientdata.shape
# Out:
# (40474, 30)

# %%
# Kolumny w train_inpatientdata bez żadnych braków (bez NaN)
non_nan_columns = train_inpatientdata.columns[train_inpatientdata.notnull().all()]
print("Kolumny bez NaN w train_inpatientdata:")
print(non_nan_columns)
# Out:
# Kolumny bez NaN w train_inpatientdata:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DischargeDt', 'DiagnosisGroupCode', 'ClmDiagnosisCode_1'],
#       dtype='object')

# %%
train_provider.head()
# Out:
#    Provider PotentialFraud  FraudFlag
# 0  PRV51001             No          0
# 1  PRV51003            Yes          1
# 2  PRV51004             No          0
# 3  PRV51005            Yes          1
# 4  PRV51007             No          0

# %%
train_provider.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5410 entries, 0 to 5409
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provider        5410 non-null   object
#  1   PotentialFraud  5410 non-null   category
#  2   FraudFlag       5410 non-null   int64
# dtypes: category(1), int64(1), object(1)
# memory usage: 90.1+ KB

# %%
train_provider.isnull().sum()
# Out:
# Provider          0
# PotentialFraud    0
# FraudFlag         0
# dtype: int64

# %%
train_provider.duplicated().sum()
# Out:
# 0

# %%
train_inpatientdata = pd.read_csv('Train_Inpatientdata-1542865627584.csv')
train_outpatientdata = pd.read_csv('Train_Outpatientdata-1542865627584.csv')

# %%
train_claims = pd.concat([train_inpatientdata, train_outpatientdata], axis=0)
train_claims.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %%
train_claims_with_beneficiary = train_claims.merge(train_beneficiary, on='BeneID', how='left')
train_claims_with_beneficiary.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6        DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0                 NaN 1943-01-01  NaN       1     1                     0
# 1                 NaN 1943-01-01  NaN       1     1                     0
# 2                 NaN 1943-01-01  NaN       1     1                     0
# 3                 NaN 1914-03-01  NaN       2     2                     0
# 4                 NaN 1938-04-01  NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0     39     230                   12                   12
# 1     39     230                   12                   12
# 2     39     230                   12                   12
# 3      1     360                   12                   12
# 4     45     780                   12                   12
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         2                          1
# 1                      1                         2                          1
# 2                      1                         2                          1
# 3                      2                         1                          1
# 4                      2                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# 0                   2                           2                       1
# 1                   2                           2                       1
# 2                   2                           2                       1
# 3                   2                           2                       1
# 4                   2                           1                       1
#
#    ChronicCond_Diabetes  ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                     1                          1                         2
# 1                     1                          1                         2
# 2                     1                          1                         2
# 3                     1                          2                         2
# 4                     2                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt  Age
# 0                     70   67
# 1                     70   67
# 2                     70   67
# 3                    320   95
# 4                    100   71

# %%
all_data= train_claims_with_beneficiary.merge(train_provider, on='Provider', how='left')
all_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6        DOB  DOD  Gender  Race RenalDiseaseIndicator  \
# 0                 NaN 1943-01-01  NaN       1     1                     0
# 1                 NaN 1943-01-01  NaN       1     1                     0
# 2                 NaN 1943-01-01  NaN       1     1                     0
# 3                 NaN 1914-03-01  NaN       2     2                     0
# 4                 NaN 1938-04-01  NaN       2     1                     Y
#
#    State  County  NoOfMonths_PartACov  NoOfMonths_PartBCov  \
# 0     39     230                   12                   12
# 1     39     230                   12                   12
# 2     39     230                   12                   12
# 3      1     360                   12                   12
# 4     45     780                   12                   12
#
#    ChronicCond_Alzheimer  ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                      1                         2                          1
# 1                      1                         2                          1
# 2                      1                         2                          1
# 3                      2                         1                          1
# 4                      2                         1                          1
#
#    ChronicCond_Cancer  ChronicCond_ObstrPulmonary  ChronicCond_Depression  \
# 0                   2                           2                       1
# 1                   2                           2                       1
# 2                   2                           2                       1
# 3                   2                           2                       1
# 4                   2                           1                       1
#
#    ChronicCond_Diabetes  ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                     1                          1                         2
# 1                     1                          1                         2
# 2                     1                          1                         2
# 3                     1                          2                         2
# 4                     2                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt  Age PotentialFraud  FraudFlag
# 0                     70   67            Yes          1
# 1                     70   67             No          0
# 2                     70   67             No          0
# 3                    320   95             No          0
# 4                    100   71             No          0

# %%
all_data.shape
# Out:
# (558211, 57)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558211 entries, 0 to 558210
# Data columns (total 57 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   BeneID                           558211 non-null  object
#  1   ClaimID                          558211 non-null  object
#  2   ClaimStartDt                     558211 non-null  object
#  3   ClaimEndDt                       558211 non-null  object
#  4   Provider                         558211 non-null  object
#  5   InscClaimAmtReimbursed           558211 non-null  int64
#  6   AttendingPhysician               556703 non-null  object
#  7   OperatingPhysician               114447 non-null  object
#  8   OtherPhysician                   199736 non-null  object
#  9   AdmissionDt                      40474 non-null   object
#  10  ClmAdmitDiagnosisCode            145899 non-null  object
#  11  DeductibleAmtPaid                557312 non-null  float64
#  12  DischargeDt                      40474 non-null   object
#  13  DiagnosisGroupCode               40474 non-null   object
#  14  ClmDiagnosisCode_1               547758 non-null  object
#  15  ClmDiagnosisCode_2               362605 non-null  object
#  16  ClmDiagnosisCode_3               243055 non-null  object
#  17  ClmDiagnosisCode_4               164536 non-null  object
#  18  ClmDiagnosisCode_5               111924 non-null  object
#  19  ClmDiagnosisCode_6               84392 non-null   object
#  20  ClmDiagnosisCode_7               66177 non-null   object
#  21  ClmDiagnosisCode_8               53444 non-null   object
#  22  ClmDiagnosisCode_9               41815 non-null   object
#  23  ClmDiagnosisCode_10              5010 non-null    object
#  24  ClmProcedureCode_1               23310 non-null   float64
#  25  ClmProcedureCode_2               5490 non-null    float64
#  26  ClmProcedureCode_3               969 non-null     float64
#  27  ClmProcedureCode_4               118 non-null     float64
#  28  ClmProcedureCode_5               9 non-null       float64
#  29  ClmProcedureCode_6               0 non-null       float64
#  30  DOB                              558211 non-null  datetime64[ns]
#  31  DOD                              4131 non-null    object
#  32  Gender                           558211 non-null  int64
#  33  Race                             558211 non-null  int64
#  34  RenalDiseaseIndicator            558211 non-null  object
#  35  State                            558211 non-null  int64
#  36  County                           558211 non-null  int64
#  37  NoOfMonths_PartACov              558211 non-null  int64
#  38  NoOfMonths_PartBCov              558211 non-null  int64
#  39  ChronicCond_Alzheimer            558211 non-null  int64
#  40  ChronicCond_Heartfailure         558211 non-null  int64
#  41  ChronicCond_KidneyDisease        558211 non-null  int64
#  42  ChronicCond_Cancer               558211 non-null  int64
#  43  ChronicCond_ObstrPulmonary       558211 non-null  int64
#  44  ChronicCond_Depression           558211 non-null  int64
#  45  ChronicCond_Diabetes             558211 non-null  int64
#  46  ChronicCond_IschemicHeart        558211 non-null  int64
#  47  ChronicCond_Osteoporasis         558211 non-null  int64
#  48  ChronicCond_rheumatoidarthritis  558211 non-null  int64
#  49  ChronicCond_stroke               558211 non-null  int64
#  50  IPAnnualReimbursementAmt         558211 non-null  int64
#  51  IPAnnualDeductibleAmt            558211 non-null  int64
#  52  OPAnnualReimbursementAmt         558211 non-null  int64
#  53  OPAnnualDeductibleAmt            558211 non-null  int64
#  54  Age                              558211 non-null  int64
#  55  PotentialFraud                   558211 non-null  category
#  56  FraudFlag                        558211 non-null  int64
# dtypes: category(1), datetime64[ns](1), float64(7), int64(24), object(24)
# memory usage: 239.0+ MB

# %% [markdown]
# Te kolumny które powinny miec typ data zostana przeksztalcony typ

# %%
import pandas as pd

date_cols = ['ClaimStartDt', 'ClaimEndDt', 'AdmissionDt', 'DischargeDt', 'DOB', 'DOD']

for col in date_cols:
    all_data[col] = pd.to_datetime(all_data[col], errors='coerce')

# %%
# Czy w zbiorze występują brakujące wartości (NaN, null)?

# %%
missing_values = all_data.isnull().sum()
missing_values
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1508
# OperatingPhysician                 443764
# OtherPhysician                     358475
# AdmissionDt                        517737
# ClmAdmitDiagnosisCode              412312
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                 517737
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195606
# ClmDiagnosisCode_3                 315156
# ClmDiagnosisCode_4                 393675
# ClmDiagnosisCode_5                 446287
# ClmDiagnosisCode_6                 473819
# ClmDiagnosisCode_7                 492034
# ClmDiagnosisCode_8                 504767
# ClmDiagnosisCode_9                 516396
# ClmDiagnosisCode_10                553201
# ClmProcedureCode_1                 534901
# ClmProcedureCode_2                 552721
# ClmProcedureCode_3                 557242
# ClmProcedureCode_4                 558093
# ClmProcedureCode_5                 558202
# ClmProcedureCode_6                 558211
# DOB                                     0
# DOD                                554080
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# Age                                     0
# PotentialFraud                          0
# FraudFlag                               0
# dtype: int64

# %%
# W zbiorze jest pełno brakujących wartości, dodatkowo są niektóre braki ukryte bo 2 w ClmDiagnosis to tez są brakujące dane

# %%
all_data.nunique()
# Out:
# BeneID                             138556
# ClaimID                            558211
# ClaimStartDt                          398
# ClaimEndDt                            366
# Provider                             5410
# InscClaimAmtReimbursed                438
# AttendingPhysician                  82063
# OperatingPhysician                  35315
# OtherPhysician                      46457
# AdmissionDt                           398
# ClmAdmitDiagnosisCode                4098
# DeductibleAmtPaid                      17
# DischargeDt                           365
# DiagnosisGroupCode                    736
# ClmDiagnosisCode_1                  10450
# ClmDiagnosisCode_2                   5300
# ClmDiagnosisCode_3                   4756
# ClmDiagnosisCode_4                   4359
# ClmDiagnosisCode_5                   3970
# ClmDiagnosisCode_6                   3607
# ClmDiagnosisCode_7                   3388
# ClmDiagnosisCode_8                   3070
# ClmDiagnosisCode_9                   2774
# ClmDiagnosisCode_10                  1158
# ClmProcedureCode_1                   1117
# ClmProcedureCode_2                    300
# ClmProcedureCode_3                    154
# ClmProcedureCode_4                     48
# ClmProcedureCode_5                      6
# ClmProcedureCode_6                      0
# DOB                                   900
# DOD                                    11
# Gender                                  2
# Race                                    4
# RenalDiseaseIndicator                   2
# State                                  52
# County                                314
# NoOfMonths_PartACov                    13
# NoOfMonths_PartBCov                    13
# ChronicCond_Alzheimer                   2
# ChronicCond_Heartfailure                2
# ChronicCond_KidneyDisease               2
# ChronicCond_Cancer                      2
# ChronicCond_ObstrPulmonary              2
# ChronicCond_Depression                  2
# ChronicCond_Diabetes                    2
# ChronicCond_IschemicHeart               2
# ChronicCond_Osteoporasis                2
# ChronicCond_rheumatoidarthritis         2
# ChronicCond_stroke                      2
# IPAnnualReimbursementAmt             3004
# IPAnnualDeductibleAmt                 147
# OPAnnualReimbursementAmt             2078
# OPAnnualDeductibleAmt                 789
# Age                                    76
# PotentialFraud                          2
# FraudFlag                               2
# dtype: int64

# %%
all_data.isna().sum()
# Out:
# BeneID                                  0
# ClaimID                                 0
# ClaimStartDt                            0
# ClaimEndDt                              0
# Provider                                0
# InscClaimAmtReimbursed                  0
# AttendingPhysician                   1508
# OperatingPhysician                 443764
# OtherPhysician                     358475
# AdmissionDt                        517737
# ClmAdmitDiagnosisCode              412312
# DeductibleAmtPaid                     899
# DischargeDt                        517737
# DiagnosisGroupCode                 517737
# ClmDiagnosisCode_1                  10453
# ClmDiagnosisCode_2                 195606
# ClmDiagnosisCode_3                 315156
# ClmDiagnosisCode_4                 393675
# ClmDiagnosisCode_5                 446287
# ClmDiagnosisCode_6                 473819
# ClmDiagnosisCode_7                 492034
# ClmDiagnosisCode_8                 504767
# ClmDiagnosisCode_9                 516396
# ClmDiagnosisCode_10                553201
# ClmProcedureCode_1                 534901
# ClmProcedureCode_2                 552721
# ClmProcedureCode_3                 557242
# ClmProcedureCode_4                 558093
# ClmProcedureCode_5                 558202
# ClmProcedureCode_6                 558211
# DOB                                     0
# DOD                                554080
# Gender                                  0
# Race                                    0
# RenalDiseaseIndicator                   0
# State                                   0
# County                                  0
# NoOfMonths_PartACov                     0
# NoOfMonths_PartBCov                     0
# ChronicCond_Alzheimer                   0
# ChronicCond_Heartfailure                0
# ChronicCond_KidneyDisease               0
# ChronicCond_Cancer                      0
# ChronicCond_ObstrPulmonary              0
# ChronicCond_Depression                  0
# ChronicCond_Diabetes                    0
# ChronicCond_IschemicHeart               0
# ChronicCond_Osteoporasis                0
# ChronicCond_rheumatoidarthritis         0
# ChronicCond_stroke                      0
# IPAnnualReimbursementAmt                0
# IPAnnualDeductibleAmt                   0
# OPAnnualReimbursementAmt                0
# OPAnnualDeductibleAmt                   0
# Age                                     0
# PotentialFraud                          0
# FraudFlag                               0
# dtype: int64

# %%
null_summary = pd.DataFrame({
    'Null Count': all_data.isnull().sum(),
    'Null Percentage': (all_data.isnull().sum() / len(all_data)) * 100,
    'Unique Values': all_data.nunique()
})

null_summary_sorted = null_summary.sort_values(by='Null Percentage', ascending=False)

print(null_summary_sorted)
# Out:
#                                  Null Count  Null Percentage  Unique Values
# ClmProcedureCode_6                   558211       100.000000              0
# ClmProcedureCode_5                   558202        99.998388              6
# ClmProcedureCode_4                   558093        99.978861             48
# ClmProcedureCode_3                   557242        99.826410            154
# DOD                                  554080        99.259957             11
# ClmDiagnosisCode_10                  553201        99.102490           1158
# ClmProcedureCode_2                   552721        99.016501            300
# ClmProcedureCode_1                   534901        95.824160           1117
# DiagnosisGroupCode                   517737        92.749337            736
# AdmissionDt                          517737        92.749337            398
# DischargeDt                          517737        92.749337            365
# ClmDiagnosisCode_9                   516396        92.509105           2774
# ClmDiagnosisCode_8                   504767        90.425843           3070
# ClmDiagnosisCode_7                   492034        88.144805           3388
# ClmDiagnosisCode_6                   473819        84.881702           3607
# ClmDiagnosisCode_5                   446287        79.949517           3970
# OperatingPhysician                   443764        79.497538          35315
# ClmAdmitDiagnosisCode                412312        73.863109           4098
# ClmDiagnosisCode_4                   393675        70.524407           4359
# OtherPhysician                       358475        64.218548          46457
# ClmDiagnosisCode_3                   315156        56.458221           4756
# ClmDiagnosisCode_2                   195606        35.041588           5300
# ClmDiagnosisCode_1                    10453         1.872589          10450
# AttendingPhysician                     1508         0.270149          82063
# DeductibleAmtPaid                       899         0.161050             17
# ChronicCond_stroke                        0         0.000000              2
# ChronicCond_Depression                    0         0.000000              2
# ChronicCond_ObstrPulmonary                0         0.000000              2
# ChronicCond_Diabetes                      0         0.000000              2
# ChronicCond_IschemicHeart                 0         0.000000              2
# ChronicCond_Osteoporasis                  0         0.000000              2
# ChronicCond_rheumatoidarthritis           0         0.000000              2
# OPAnnualDeductibleAmt                     0         0.000000            789
# PotentialFraud                            0         0.000000              2
# IPAnnualReimbursementAmt                  0         0.000000           3004
# Age                                       0         0.000000             76
# IPAnnualDeductibleAmt                     0         0.000000            147
# OPAnnualReimbursementAmt                  0         0.000000           2078
# ChronicCond_KidneyDisease                 0         0.000000              2
# ChronicCond_Cancer                        0         0.000000              2
# BeneID                                    0         0.000000         138556
# ChronicCond_Heartfailure                  0         0.000000              2
# ChronicCond_Alzheimer                     0         0.000000              2
# NoOfMonths_PartBCov                       0         0.000000             13
# NoOfMonths_PartACov                       0         0.000000             13
# County                                    0         0.000000            314
# State                                     0         0.000000             52
# RenalDiseaseIndicator                     0         0.000000              2
# Race                                      0         0.000000              4
# Gender                                    0         0.000000              2
# DOB                                       0         0.000000            900
# ClaimID                                   0         0.000000         558211
# InscClaimAmtReimbursed                    0         0.000000            438
# Provider                                  0         0.000000           5410
# ClaimEndDt                                0         0.000000            366
# ClaimStartDt                              0         0.000000            398
# FraudFlag                                 0         0.000000              2

# %%
# ToDO należy zmniejszyć wymiar danych ponizej 15% braków null/nan to wyrzucamy lub robimy agregacje

# %%
# Daty śmierci nie jest wypełniona bo oznacza ze pacjent żyje. ClmProcedure nie zostala wypełniona bo prawdopodobnie jest tylko wypełniona tylko jak jest dany zabieg wykonywany.
# OperatingPhysician jak nie ma operacji. Są to więc braki są uzasadnione. Diagnosis group Code jest bardzo rzadko uzupełniana

# %%
all_data['ClmDiagnosisCode_7'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          2724
# 1           NaN
# 2           NaN
# 3         25062
# 4          5119
#           ...
# 558206      NaN
# 558207      NaN
# 558208      NaN
# 558209      NaN
# 558210     2724
# Name: ClmDiagnosisCode_7, Length: 558211, dtype: object>

# %%
missing_values_percentage = all_data.isna().sum() / len(all_data) * 100

plt.figure(figsize=(12, 10))
missing_values_percentage.sort_values(ascending=True).plot(kind='barh', color='coral', edgecolor='black')
plt.title('Percentage of Missing Values by Column', fontsize=16)
plt.xlabel('Percentage', fontsize=14)
plt.ylabel('Columns', fontsize=14)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
all_data['DOB'] = pd.to_datetime(all_data['DOB'])
all_data['DOD'] = pd.to_datetime(all_data['DOD'])

all_data['Age'] = all_data['DOD'].dt.year - all_data['DOB'].dt.year
all_data.drop(columns=['DOB'], inplace=True)

# %%
print(all_data['Age'].value_counts())
# Out:
# Age
# 67.0    209
# 69.0    189
# 73.0    170
# 77.0    163
# 68.0    161
#        ...
# 51.0      6
# 36.0      5
# 39.0      4
# 95.0      3
# 42.0      2
# Name: count, Length: 63, dtype: int64

# %%
stats = all_data['Age'].describe()
stats
# Out:
# count    4131.000000
# mean       74.509078
# std        11.094448
# min        36.000000
# 25%        68.000000
# 50%        75.000000
# 75%        82.000000
# max       100.000000
# Name: Age, dtype: float64

# %%
# mean i 50% są bardzo podobne

# %%
import matplotlib.pyplot as plt

age_counts = all_data['Age'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
age_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Rozkład wieku (Age)')
plt.xlabel('Wiek')
plt.ylabel('Liczba wystąpień')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
all_data['Age'].fillna(all_data['Age'].median(), inplace=True)

# %%
all_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6 DOD  Gender  Race RenalDiseaseIndicator  State  County  \
# 0                 NaN NaT       1     1                     0     39     230
# 1                 NaN NaT       1     1                     0     39     230
# 2                 NaN NaT       1     1                     0     39     230
# 3                 NaN NaT       2     2                     0      1     360
# 4                 NaN NaT       2     1                     Y     45     780
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                   12                   12                      1
# 1                   12                   12                      1
# 2                   12                   12                      1
# 3                   12                   12                      2
# 4                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          1                   2
# 2                         2                          1                   2
# 3                         1                          1                   2
# 4                         1                          1                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       1                     1
# 2                           2                       1                     1
# 3                           2                       1                     1
# 4                           1                       1                     2
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          1                         2
# 2                          1                         2
# 3                          2                         2
# 4                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt   Age PotentialFraud  FraudFlag
# 0                     70  75.0            Yes          1
# 1                     70  75.0             No          0
# 2                     70  75.0             No          0
# 3                    320  75.0             No          0
# 4                    100  75.0             No          0

# %%
print(all_data['PotentialFraud'].isnull().sum())
# Out:
# 0

# %%
all_data['isAlive'] = all_data['DOD'].isna().astype(int)
all_data.head()
# Out:
#       BeneID   ClaimID ClaimStartDt ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12 2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31 2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17 2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14 2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13 2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
#   OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0            NaN  2009-04-12                  7866             1068.0
# 1            NaN  2009-08-31                  6186             1068.0
# 2      PHY324689  2009-09-17                 29590             1068.0
# 3      PHY349768  2009-02-14                   431             1068.0
# 4            NaN  2009-08-13                 78321             1068.0
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6 DOD  Gender  Race RenalDiseaseIndicator  State  County  \
# 0                 NaN NaT       1     1                     0     39     230
# 1                 NaN NaT       1     1                     0     39     230
# 2                 NaN NaT       1     1                     0     39     230
# 3                 NaN NaT       2     2                     0      1     360
# 4                 NaN NaT       2     1                     Y     45     780
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                   12                   12                      1
# 1                   12                   12                      1
# 2                   12                   12                      1
# 3                   12                   12                      2
# 4                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          1                   2
# 2                         2                          1                   2
# 3                         1                          1                   2
# 4                         1                          1                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       1                     1
# 2                           2                       1                     1
# 3                           2                       1                     1
# 4                           1                       1                     2
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          1                         2
# 2                          1                         2
# 3                          2                         2
# 4                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt   Age PotentialFraud  FraudFlag  isAlive
# 0                     70  75.0            Yes          1        1
# 1                     70  75.0             No          0        1
# 2                     70  75.0             No          0        1
# 3                    320  75.0             No          0        1
# 4                    100  75.0             No          0        1

# %%
 #Czy występuje niezrównoważenie klas (np. dużo więcej 0 niż 1)?

print(all_data['PotentialFraud'].value_counts())
print(all_data['PotentialFraud'].value_counts(normalize=True) * 100)
# Out:
# PotentialFraud
# No     345415
# Yes    212796
# Name: count, dtype: int64
# PotentialFraud
# No     61.878931
# Yes    38.121069
# Name: proportion, dtype: float64

# %% [markdown]
# Over/Undesampling wyrównanie klasy - to zalezy przemyślec na podstawie liczby row - przy dużej undersampling, jak mala liczba danych oversampling

# %%
# Tak jest więcej nie oszust ok 61% a 38 % jest oszustw

#  Czy kolumna istnieje i ma odpowiedni typ (binary, Yes/No, 0/1)?
#  Czy występuje niezrównoważenie klas (np. dużo więcej 0 niż 1)?
#  Czy klasy są poprawnie zakodowane?

# Tak mamy w provider data dwie kolumny 0/1

# %%
#Czy są zduplikowane wiersze (df.duplicated().sum())?

all_data.duplicated().sum()

#Nie ma
# Out:
# 0

# %%
#Czy są zduplikowane identyfikatory (Provider, ClaimID itd.)?
print('Zduplikowane ClaimID:', all_data['ClaimID'].duplicated().sum())
print('Zduplikowane BeneID:', all_data['BeneID'].duplicated().sum())
print('Zduplikowane Provider:', all_data['Provider'].duplicated().sum())
# Out:
# Zduplikowane ClaimID: 0
# Zduplikowane BeneID: 419655
# Zduplikowane Provider: 552801

# %% [markdown]
# BeneID i Provider się powtarzają. Sprawdzmy ile przeciętnie claimów jest per clienta, a ile jest per clienta frauda.

# %%
avg_claims_per_client = all_data.groupby('BeneID')['ClaimID'].nunique().mean()
print(f"Średnia liczba zgłoszeń na klienta: {avg_claims_per_client:.2f}")

# Średnio mamy 4 claimy.
# Out:
# Średnia liczba zgłoszeń na klienta: 4.03

# %%
fraud_providers = all_data[all_data['PotentialFraud'] == 'Yes']['Provider'].unique()
fraud_clients = all_data[all_data['Provider'].isin(fraud_providers)]

avg_claims_per_fraud_client = fraud_clients.groupby('BeneID')['ClaimID'].nunique().mean()
print(f"Średnia liczba zgłoszeń na klienta z fraudowym providerem: {avg_claims_per_fraud_client:.2f}")
# Out:
# Średnia liczba zgłoszeń na klienta z fraudowym providerem: 2.53

# %%
# Średnia liczba zgłoszen na klienta jest 2.53, czyli raczej ten który nie korzysta intensywnie

# %%
# A co z żyjący i nie żyjący

# %%
claims_per_client = all_data.groupby(['BeneID', 'isAlive'])['ClaimID'].nunique().reset_index()
avg_claims_alive_status = claims_per_client.groupby('isAlive')['ClaimID'].mean()

import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x=avg_claims_alive_status.index, y=avg_claims_alive_status.values, palette='pastel')
plt.xticks([0, 1], ['Zmarli', 'Żyjący'])
plt.ylabel('Średnia liczba roszczeń')
plt.title('Średnia liczba zgłoszeń na klienta\nw zależności od stanu życia')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
# Więcej fraudów chociaz niewiele więcej jest na żyjących

# %%
all_data['WasOperated'] = all_data['OperatingPhysician'].notna().astype(int)
operated_counts = all_data['WasOperated'].value_counts()
operated_percent = all_data['WasOperated'].value_counts(normalize=True) * 100
print(operated_counts)
print(operated_percent.round(2))

import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='WasOperated', data=all_data, palette='Set2')
plt.xticks([0, 1], ['Nieoperowani', 'Operowani'])
plt.title('Liczba osób operowanych vs nieoperowanych')
plt.ylabel('Liczba przypadków')
plt.xlabel('Status operacji')
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# WasOperated
# 0    443764
# 1    114447
# Name: count, dtype: int64
# WasOperated
# 0    79.5
# 1    20.5
# Name: proportion, dtype: float64

# %%
# Widać wyrażna tendencje że nie operowani raczej jest fraud
# A wrod operowanych to jakie operacje byly sfingwane

# %%
fraud_operated = all_data[
    (all_data['WasOperated'] == 1) & 
    (all_data['FraudFlag'] == 1)
]

fraud_by_diag = fraud_operated.groupby('DiagnosisGroupCode')['ClaimID'].count().sort_values(ascending=False)
print(fraud_by_diag.head(10))
# Out:
# DiagnosisGroupCode
# 286    59
# 864    55
# 316    53
# 252    52
# 862    51
# 242    50
# 244    48
# 248    48
# 303    47
# 307    47
# Name: ClaimID, dtype: int64

# %%
fraud_by_diag.head(10).plot(kind='bar', figsize=(12,6), color='tomato')
plt.title('Top 10 Diagnosis Groups with Fraudulent Claims and Operations')
plt.ylabel('Number of Fraudulent Claims')
plt.xlabel('Diagnosis Group Code')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
print(all_data.columns.tolist())
# Out:
# ['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider', 'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode', 'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease', 'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression', 'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke', 'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag', 'isAlive', 'WasOperated']

# %%
fraud_with_diag = all_data[
    (all_data['FraudFlag'] == 1) &
    (all_data['DiagnosisGroupCode'].notna())
]

count_fraud_with_diag = fraud_with_diag.shape[0]
print(f"Liczba fraudów z wypełnionym DiagnosisGroupCode: {count_fraud_with_diag}")
# Out:
# Liczba fraudów z wypełnionym DiagnosisGroupCode: 23402

# %%
fraud_with_diag = all_data[
    (all_data['FraudFlag'] == 1) &
    (all_data['DiagnosisGroupCode'].notna())
]

all_claims_with_diag = all_data[
    (all_data['DiagnosisGroupCode'].notna())
]
count_fraud_with_diag = fraud_with_diag.shape[0]
total_fraud = all_claims_with_diag.shape[0]

percentage = (count_fraud_with_diag / total_fraud) * 100

print(f"Procent fraudów z wypełnionym DiagnosisGroupCode: {percentage:.2f}%")
# Out:
# Procent fraudów z wypełnionym DiagnosisGroupCode: 57.82%

# %%
# Ponad połowe ma wypelnione 57.82%

# %%
# A jak od racy fraud zalezy

# %%
fraud_by_race = all_data.groupby('Race')['FraudFlag'].mean() * 100
print(fraud_by_race)

fraud_by_race.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Procent fraudów w zależności od rasy')
plt.xlabel('Race')
plt.ylabel('Procent fraudów [%]')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Race
# 1    37.862287
# 2    36.455787
# 3    45.457773
# 5    44.035533
# Name: FraudFlag, dtype: float64

# %% [markdown]
# Najwięcej jest fraudów w rasie 3 i 5
# Nie ma wsród fraudow Azjatyckich danych a najwięcej jest fraudow z Hispanic

# %%
all_data['Race'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Race'>

# %%
fraud_counts_gender = all_data[all_data['FraudFlag'] == 1].groupby('Gender').size()
print(fraud_counts_gender)
# Out:
# Gender
# 1     89683
# 2    123113
# dtype: int64

# %%
plt.figure(figsize=(6,4))
sns.barplot(x=fraud_counts_gender.index, y=fraud_counts_gender.values, palette='pastel')
plt.title('Liczba fraudów według płci')
plt.xlabel('Gender')
plt.ylabel('Liczba fraudów')
plt.xticks(ticks=fraud_counts_gender.index, labels=['Male', 'Female']) 
plt.tight_layout()
plt.show()

# %%
fraud_ratio_gender = all_data.groupby('Gender')['FraudFlag'].mean() * 100
fraud_ratio_gender
# Out:
# Gender
# 1    38.147233
# 2    38.102032
# Name: FraudFlag, dtype: float64

# %% [markdown]
# Jest więcej fraudow na mezczyznach ilosciowo ale procentowo jest wyrownanie

# %%
# Ile per dekada jest fraudow

# %%
all_data['AgeGroup'] = (all_data['Age'] // 10) * 10

fraud_by_agegroup = all_data[all_data['FraudFlag'] == 1].groupby('AgeGroup').size()
total_by_agegroup = all_data.groupby('AgeGroup').size()
fraud_ratio = (fraud_by_agegroup / total_by_agegroup) * 100

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.barplot(x=fraud_ratio.index, y=fraud_ratio.values, palette='viridis')
plt.title('Procent fraudów w grupach wiekowych (dekady)')
plt.xlabel('Wiek (przedziały co 10 lat)')
plt.ylabel('Procent fraudów [%]')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Najmniej jest fraudow la 40 latkow i 100 latków

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag',
#        'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
alzheimers = all_data[all_data['ChronicCond_Alzheimer'] == 1]
fraud_ratio_alzheimers = alzheimers['FraudFlag'].mean() * 100
print(f'Procent fraudów wśród chorych na Alzheimera: {fraud_ratio_alzheimers:.2f}%')
# Out:
# Procent fraudów wśród chorych na Alzheimera: 38.49%

# %%
chronic_conditions = [
    'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
    'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
    'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
    'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
    'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
    'ChronicCond_stroke'
]

fraud_percentages = {}

for cond in chronic_conditions:
    subset = all_data[all_data[cond] == 1]
    fraud_percent = subset[subset['FraudFlag'] == 1].shape[0] / all_data[all_data['FraudFlag'] == 1].shape[0] * 100
    fraud_percentages[cond] = fraud_percent

fraud_percent_df = pd.DataFrame.from_dict(fraud_percentages, orient='index', columns=['Fraud %']).sort_values(by='Fraud %', ascending=False)
print(fraud_percent_df)

#ile jest fraudow per choroba przewlekla na wszystkie fraudy
# Out:
#                                    Fraud %
# ChronicCond_IschemicHeart        76.369857
# ChronicCond_Diabetes             70.849546
# ChronicCond_Heartfailure         59.609203
# ChronicCond_Depression           43.510216
# ChronicCond_KidneyDisease        42.222128
# ChronicCond_Alzheimer            40.577360
# ChronicCond_ObstrPulmonary       32.006241
# ChronicCond_Osteoporasis         31.834715
# ChronicCond_rheumatoidarthritis  31.411775
# ChronicCond_Cancer               15.309498
# ChronicCond_stroke               10.524634

# %% [markdown]
# Najczęsciej oszukują na chronic
# ChronicCond_IschemicHeart        76.369857
# ChronicCond_Diabetes             70.849546
# ChronicCond_Heartfailure         59.609203
# ChronicCond_Depression           43.510216

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag',
#        'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
corr_df = all_data.copy()

correlation = corr_df.select_dtypes(include=['number']).corr()

sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelacje')
plt.show()
# Out:
# C:\Users\tolki\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag',
#        'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
cols = ['ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
        'OPAnnualDeductibleAmt', 'PotentialFraud', 'FraudFlag', 'Age',
        'isAlive', 'WasOperated', 'AgeGroup']

corr_df = all_data[cols]

correlation = corr_df.select_dtypes(include=['number']).corr()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelacje')
plt.show()

# %%
cols = [ 'IPAnnualReimbursementAmt',
        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
        'OPAnnualDeductibleAmt', 'PotentialFraud', 'Age',
        'isAlive', 'WasOperated', 'AgeGroup', 'FraudFlag']

corr_df = all_data[cols]

correlation = corr_df.select_dtypes(include=['number']).corr()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelacje')
plt.show()

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag',
#        'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
cols = ['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
       'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
       'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
       'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
       'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
       'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
       'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
       'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
       'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
       'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
       'State', 'County', 'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
       'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
       'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
       'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
       'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
       'ChronicCond_stroke','FraudFlag']

corr_df2 = all_data[cols]

correlation = corr_df2.select_dtypes(include=['number']).corr()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelacje')
plt.show()
# Out:
# C:\Users\tolki\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# widaź wyrazna zależnoc CLM_procedure_5

# %%
fraud_counts_nonnull = all_data[(all_data['FraudFlag'] == 1) & (all_data['ClmProcedureCode_5'].notna())]['ClmProcedureCode_5'].value_counts()
print(fraud_counts_nonnull)
# Out:
# ClmProcedureCode_5
# 4139.0    2
# 5185.0    1
# 9971.0    1
# 2724.0    1
# 9982.0    1
# Name: count, dtype: int64

# %%
total_counts = all_data['ClmProcedureCode_5'].value_counts(dropna=False)
fraud_counts = all_data[all_data['FraudFlag'] == 1]['ClmProcedureCode_5'].value_counts(dropna=False)

fraud_percent = (fraud_counts / total_counts) * 100
fraud_percent = fraud_percent.sort_values(ascending=False)

print(fraud_percent)
# Out:
# ClmProcedureCode_5
# 5185.0    100.000000
# 9971.0    100.000000
# 9982.0    100.000000
# 4139.0     66.666667
# 2724.0     50.000000
# NaN        38.120609
# 4422.0           NaN
# Name: count, dtype: float64

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'ClaimStartDt', 'ClaimEndDt', 'Provider',
#        'InscClaimAmtReimbursed', 'AttendingPhysician', 'OperatingPhysician',
#        'OtherPhysician', 'AdmissionDt', 'ClmAdmitDiagnosisCode',
#        'DeductibleAmtPaid', 'DischargeDt', 'DiagnosisGroupCode',
#        'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
#        'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
#        'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
#        'ClmDiagnosisCode_10', 'ClmProcedureCode_1', 'ClmProcedureCode_2',
#        'ClmProcedureCode_3', 'ClmProcedureCode_4', 'ClmProcedureCode_5',
#        'ClmProcedureCode_6', 'DOD', 'Gender', 'Race', 'RenalDiseaseIndicator',
#        'State', 'County', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov',
#        'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
#        'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
#        'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
#        'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
#        'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
#        'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
#        'IPAnnualDeductibleAmt', 'OPAnnualReimbursementAmt',
#        'OPAnnualDeductibleAmt', 'Age', 'PotentialFraud', 'FraudFlag',
#        'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
#all_data = all_data.drop(['ClaimStartDt', 'ClaimEndDt','PotentialFraud', 'AgeGroup', 'DOD', 'NoOfMonths_PartACov', 'NoOfMonths_PartBCov','OPAnnualDeductibleAmt', 'IPAnnualDeductibleAmt'],axis=1)
all_data = all_data.drop(['ClaimStartDt', 'ClaimEndDt'],axis=1)

# %%
all_data.columns
# Out:
# Index(['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
#        'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
#        'AdmissionDt', 'ClmAdmitDiagnosisCode', 'DeductibleAmtPaid',
#        'DischargeDt', 'DiagnosisGroupCode', 'ClmDiagnosisCode_1',
#        'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4',
#        'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7',
#        'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10',
#        'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3',
#        'ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6', 'DOD',
#        'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
#        'NoOfMonths_PartACov', 'NoOfMonths_PartBCov', 'ChronicCond_Alzheimer',
#        'ChronicCond_Heartfailure', 'ChronicCond_KidneyDisease',
#        'ChronicCond_Cancer', 'ChronicCond_ObstrPulmonary',
#        'ChronicCond_Depression', 'ChronicCond_Diabetes',
#        'ChronicCond_IschemicHeart', 'ChronicCond_Osteoporasis',
#        'ChronicCond_rheumatoidarthritis', 'ChronicCond_stroke',
#        'IPAnnualReimbursementAmt', 'IPAnnualDeductibleAmt',
#        'OPAnnualReimbursementAmt', 'OPAnnualDeductibleAmt', 'Age',
#        'PotentialFraud', 'FraudFlag', 'isAlive', 'WasOperated', 'AgeGroup'],
#       dtype='object')

# %%
all_data = all_data.drop(['DeductibleAmtPaid'],axis=1)

# %%
cols = ['BeneID', 'ClaimID', 'Provider', 'InscClaimAmtReimbursed',
       'AttendingPhysician', 'OperatingPhysician', 'OtherPhysician',
       'AdmissionDt', 'ClmAdmitDiagnosisCode',
       'DischargeDt', 'DiagnosisGroupCode', 'ClmDiagnosisCode_1',
       'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4',
       'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7',
       'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10',
       'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3',
       'ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6',
       'Gender', 'Race', 'RenalDiseaseIndicator', 'State', 'County',
       'ChronicCond_Alzheimer', 'ChronicCond_Heartfailure',
       'ChronicCond_KidneyDisease', 'ChronicCond_Cancer',
       'ChronicCond_ObstrPulmonary', 'ChronicCond_Depression',
       'ChronicCond_Diabetes', 'ChronicCond_IschemicHeart',
       'ChronicCond_Osteoporasis', 'ChronicCond_rheumatoidarthritis',
       'ChronicCond_stroke', 'IPAnnualReimbursementAmt',
       'OPAnnualReimbursementAmt', 'FraudFlag', 'Age', 'isAlive',
       'WasOperated']

corr_df3 = all_data[cols]

correlation = corr_df3.select_dtypes(include=['number']).corr()

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 10))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Korelacje')
plt.show()
# Out:
# C:\Users\tolki\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)

# %%
# Melt: przekształcenie danych z szerokiego formatu do długiego
all_data_melted = all_data.melt(var_name='original_column', value_name='value')
# Dodanie nowej kolumny z ostatnią literą nazwy kolumny
all_data_melted['last_letter'] = all_data_melted['original_column'].str[-1]

# %%
print(all_data_melted.head())
# Out:
#   original_column      value last_letter
# 0          BeneID  BENE11001           D
# 1          BeneID  BENE11001           D
# 2          BeneID  BENE11001           D
# 3          BeneID  BENE11011           D
# 4          BeneID  BENE11014           D

# %%
# Wybierz kolumny, których nazwa kończy się cyfrą 1-9
digit_cols = ['ClmDiagnosisCode_1', 'ClmDiagnosisCode_2',
       'ClmDiagnosisCode_3', 'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5',
       'ClmDiagnosisCode_6', 'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8',
       'ClmDiagnosisCode_9', 'ClmDiagnosisCode_10']
# Stwórz pustą kolumnę docelową
all_data['digit_found'] = None
# Iteruj po wybranych kolumnach i przypisz cyfrę tam, gdzie wartość == 1
for col in digit_cols:
    digit = col[-1]
    mask = all_data[col] == 1
    all_data.loc[mask, 'digit_found'] = digit
display(all_data.head())
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6 DOD  Gender  Race RenalDiseaseIndicator  State  County  \
# 0                 NaN NaT       1     1                     0     39     230
# 1                 NaN NaT       1     1                     0     39     230
# 2                 NaN NaT       1     1                     0     39     230
# 3                 NaN NaT       2     2                     0      1     360
# 4                 NaN NaT       2     1                     Y     45     780
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                   12                   12                      1
# 1                   12                   12                      1
# 2                   12                   12                      1
# 3                   12                   12                      2
# 4                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          1                   2
# 2                         2                          1                   2
# 3                         1                          1                   2
# 4                         1                          1                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       1                     1
# 2                           2                       1                     1
# 3                           2                       1                     1
# 4                           1                       1                     2
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          1                         2
# 2                          1                         2
# 3                          2                         2
# 4                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt   Age PotentialFraud  FraudFlag  isAlive  \
# 0                     70  75.0            Yes          1        1
# 1                     70  75.0             No          0        1
# 2                     70  75.0             No          0        1
# 3                    320  75.0             No          0        1
# 4                    100  75.0             No          0        1
#
#    WasOperated  AgeGroup digit_found
# 0            0      70.0        None
# 1            1      70.0        None
# 2            0      70.0        None
# 3            1      70.0        None
# 4            1      70.0        None

# %%
display(all_data.head())
# Out:
#       BeneID   ClaimID  Provider  InscClaimAmtReimbursed AttendingPhysician  \
# 0  BENE11001  CLM46614  PRV55912                   26000          PHY390922
# 1  BENE11001  CLM66048  PRV55907                    5000          PHY318495
# 2  BENE11001  CLM68358  PRV56046                    5000          PHY372395
# 3  BENE11011  CLM38412  PRV52405                    5000          PHY369659
# 4  BENE11014  CLM63689  PRV56614                   10000          PHY379376
#
#   OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                NaN            NaN  2009-04-12                  7866
# 1          PHY318495            NaN  2009-08-31                  6186
# 2                NaN      PHY324689  2009-09-17                 29590
# 3          PHY392961      PHY349768  2009-02-14                   431
# 4          PHY398258            NaN  2009-08-13                 78321
#
#   DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0  2009-04-18                201               1970               4019
# 1  2009-09-02                750               6186               2948
# 2  2009-09-20                883              29623              30390
# 3  2009-02-22                067              43491               2762
# 4  2009-08-30                975                042               3051
#
#   ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5 ClmDiagnosisCode_6  \
# 0               5853               7843               2768              71590
# 1              56400                NaN                NaN                NaN
# 2              71690              34590              V1581              32723
# 3               7843              32723              V1041               4254
# 4              34400               5856              42732                486
#
#   ClmDiagnosisCode_7 ClmDiagnosisCode_8 ClmDiagnosisCode_9  \
# 0               2724              19889               5849
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3              25062              40390               4019
# 4               5119              29620              20300
#
#   ClmDiagnosisCode_10  ClmProcedureCode_1  ClmProcedureCode_2  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN              7092.0                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN               331.0                 NaN
# 4                 NaN              3893.0                 NaN
#
#    ClmProcedureCode_3  ClmProcedureCode_4  ClmProcedureCode_5  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3                 NaN                 NaN                 NaN
# 4                 NaN                 NaN                 NaN
#
#    ClmProcedureCode_6 DOD  Gender  Race RenalDiseaseIndicator  State  County  \
# 0                 NaN NaT       1     1                     0     39     230
# 1                 NaN NaT       1     1                     0     39     230
# 2                 NaN NaT       1     1                     0     39     230
# 3                 NaN NaT       2     2                     0      1     360
# 4                 NaN NaT       2     1                     Y     45     780
#
#    NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                   12                   12                      1
# 1                   12                   12                      1
# 2                   12                   12                      1
# 3                   12                   12                      2
# 4                   12                   12                      2
#
#    ChronicCond_Heartfailure  ChronicCond_KidneyDisease  ChronicCond_Cancer  \
# 0                         2                          1                   2
# 1                         2                          1                   2
# 2                         2                          1                   2
# 3                         1                          1                   2
# 4                         1                          1                   2
#
#    ChronicCond_ObstrPulmonary  ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                           2                       1                     1
# 1                           2                       1                     1
# 2                           2                       1                     1
# 3                           2                       1                     1
# 4                           1                       1                     2
#
#    ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                          1                         2
# 1                          1                         2
# 2                          1                         2
# 3                          2                         2
# 4                          1                         2
#
#    ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                1                   1
# 1                                1                   1
# 2                                1                   1
# 3                                1                   1
# 4                                2                   2
#
#    IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  OPAnnualReimbursementAmt  \
# 0                     36000                   3204                        60
# 1                     36000                   3204                        60
# 2                     36000                   3204                        60
# 3                      5000                   1068                       250
# 4                     21260                   2136                       120
#
#    OPAnnualDeductibleAmt   Age PotentialFraud  FraudFlag  isAlive  \
# 0                     70  75.0            Yes          1        1
# 1                     70  75.0             No          0        1
# 2                     70  75.0             No          0        1
# 3                    320  75.0             No          0        1
# 4                    100  75.0             No          0        1
#
#    WasOperated  AgeGroup digit_found
# 0            0      70.0        None
# 1            1      70.0        None
# 2            0      70.0        None
# 3            1      70.0        None
# 4            1      70.0        None

# %% [markdown]
# Analiza ze względu na rasę beneficjenta

# %%
fraud_percentage_df = all_data.groupby('Race')['FraudFlag'].mean().reset_index()
fraud_percentage_df['FraudFlag'] = fraud_percentage_df['FraudFlag'] * 100
fraud_percentage_df.rename(columns={'FraudFlag': 'Fraud Percentage'}, inplace=True)

print(fraud_percentage_df)
# Out:
#    Race  Fraud Percentage
# 0     1         37.862287
# 1     2         36.455787
# 2     3         45.457773
# 3     5         44.035533

# %%
fraud_percentage_df = all_data.groupby(['Race', 'AgeGroup']).agg(
    FraudFlag_mean=('FraudFlag', 'mean'),
    count=('FraudFlag', 'size')  # liczba wierszy w grupie
).reset_index()
fraud_percentage_df['FraudFlag_mean'] = fraud_percentage_df['FraudFlag_mean'] * 100
fraud_percentage_df.rename(columns={'FraudFlag_mean': 'Fraud Percentage'}, inplace=True)

print(fraud_percentage_df)
# Out:
#     Race  AgeGroup  Fraud Percentage   count
# 0      1      30.0         38.095238      21
# 1      1      40.0         25.925926      54
# 2      1      50.0         29.268293     205
# 3      1      60.0         40.486409     699
# 4      1      70.0         37.862903  468823
# 5      1      80.0         38.680203     985
# 6      1      90.0         36.440678     236
# 7      1     100.0         23.076923      13
# 8      2      30.0         27.272727      11
# 9      2      40.0         17.857143      28
# 10     2      50.0         35.483871      31
# 11     2      60.0         31.683168     101
# 12     2      70.0         36.480555   55361
# 13     2      80.0         32.352941     102
# 14     2      90.0         66.666667       6
# 15     3      50.0         75.000000       4
# 16     3      60.0         29.824561      57
# 17     3      70.0         45.503212   19614
# 18     3      80.0         41.935484      31
# 19     3      90.0         44.444444       9
# 20     5      40.0          0.000000       3
# 21     5      50.0         42.105263      19
# 22     5      60.0         23.076923      26
# 23     5      70.0         44.092809   11723
# 24     5      80.0         43.181818      44
# 25     5      90.0         60.000000       5

# %% [markdown]
# # Rasa nie ma znaczącego wpływu na oszustwa

# %%
cols = [
    'ClmDiagnosisCode_1', 'ClmDiagnosisCode_2', 'ClmDiagnosisCode_3',
    'ClmDiagnosisCode_4', 'ClmDiagnosisCode_5', 'ClmDiagnosisCode_6',
    'ClmDiagnosisCode_7', 'ClmDiagnosisCode_8', 'ClmDiagnosisCode_9',
    'ClmDiagnosisCode_10'
]

# Tworzymy nową kolumnę 'DiagnosisCount' zliczającą ile jest wartości nie-NaN w tych kolumnach
all_data['DiagnosisCount'] = all_data[cols].notnull().sum(axis=1)

# Sprawdź efekt
print(all_data[['DiagnosisCount']].head())
# Out:
#    DiagnosisCount
# 0               9
# 1               3
# 2               6
# 3               9
# 4               9

# %%
cols = [
    'ClmProcedureCode_1', 'ClmProcedureCode_2', 'ClmProcedureCode_3',
    'ClmProcedureCode_4', 'ClmProcedureCode_5', 'ClmProcedureCode_6',
]

# Tworzymy nową kolumnę 'ProceduresCount' zliczającą ile jest wartości nie-NaN w tych kolumnach
all_data['ProceduresCount'] = all_data[cols].notnull().sum(axis=1)

# Sprawdź efekt
print(all_data[['ProceduresCount']].head())
# Out:
#    ProceduresCount
# 0                0
# 1                1
# 2                0
# 3                1
# 4                1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='FraudFlag', y='DiagnosisCount', data=all_data)
plt.show()

correlation = all_data['DiagnosisCount'].corr(all_data['FraudFlag'])
print(f"Korelacja Pearsona między DiagnosisCount a FraudFlag: {correlation}")
# Out:
# Korelacja Pearsona między DiagnosisCount a FraudFlag: 0.0655238076835681

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='FraudFlag', y='ProceduresCount', data=all_data)
plt.show()

correlation = all_data['ProceduresCount'].corr(all_data['FraudFlag'])
print(f"Korelacja Pearsona między ProceduresCount a FraudFlag: {correlation}")
# Out:
# Korelacja Pearsona między ProceduresCount a FraudFlag: 0.07912935793652816

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
diag_cols = [f'ClmDiagnosisCode_{i}' for i in range(1, 11)]
all_data['DiagCount'] = all_data[diag_cols].notna().sum(axis=1)
all_data['FraudFlag'] = pd.to_numeric(all_data['FraudFlag'], errors='coerce')
summary = all_data.groupby('DiagCount')['FraudFlag'].agg(['sum', 'count']).reset_index()
summary['FraudPercent'] = (summary['sum'] / summary['count']) * 100
plt.figure(figsize=(10, 6))
sns.barplot(data=summary, x='DiagCount', y='FraudPercent', palette='Reds')
plt.title('Udział fraudów (%) względem liczby diagnoz', fontsize=14)
plt.xlabel('Liczba diagnoz (niepustych)', fontsize=12)
plt.ylabel('Procent fraudów (%)', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
top_15 = (
    all_data['ClmDiagnosisCode_1']
    .value_counts()
    .head(15)
    .index
)
df_top15 = all_data[all_data['ClmDiagnosisCode_1'].isin(top_15)]
diag_summary = (
    df_top15
    .groupby('ClmDiagnosisCode_1')['FraudFlag']
    .agg(
        total='count',
        fraud_count='sum'
    )
    .reset_index()
)
diag_summary['fraud_percent'] = (diag_summary['fraud_count'] / diag_summary['total']) * 100
diag_summary = diag_summary.sort_values(by='fraud_percent', ascending=False)
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.barplot(
    data=diag_summary,
    x='ClmDiagnosisCode_1',
    y='fraud_percent',
    palette='viridis'
)
plt.title('Procent fraudów w top 15 diagnozach (ClmDiagnosisCode_1)', fontsize=14)
plt.xlabel('Kod diagnozy', fontsize=12)
plt.ylabel('Fraud (%)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Znajdź 15 najrzadszych diagnoz (pomijając NaN)
rare_15 = (
    all_data['ClmDiagnosisCode_1']
    .value_counts(ascending=True)
    .dropna()
    .head(15)
    .index
)
# Filtrowanie danych tylko do tych diagnoz
df_rare15 = all_data[all_data['ClmDiagnosisCode_1'].isin(rare_15)]
# Podsumowanie fraudów i liczby przypadków
rare_diag_summary = (
    df_rare15
    .groupby('ClmDiagnosisCode_1')['FraudFlag']
    .agg(
        total='count',
        fraud_count='sum'
    )
    .reset_index()
)
rare_diag_summary['fraud_percent'] = (rare_diag_summary['fraud_count'] / rare_diag_summary['total']) * 100
rare_diag_summary = rare_diag_summary.sort_values(by='fraud_percent', ascending=False)
plt.figure(figsize=(12, 6))
sns.barplot(
    data=rare_diag_summary,
    x='ClmDiagnosisCode_1',
    y='fraud_percent',
    palette='magma'
)
plt.title('Procent fraudów w 15 najrzadszych diagnozach (ClmDiagnosisCode_1)', fontsize=14)
plt.xlabel('Kod diagnozy', fontsize=12)
plt.ylabel('Fraud (%)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=rare_diag_summary,
    x='ClmDiagnosisCode_1',
    y='fraud_percent',
    palette='magma'
)
plt.title('Procent fraudów w 15 najrzadszych diagnozach (ClmDiagnosisCode_1)', fontsize=14)
plt.xlabel('Kod diagnozy', fontsize=12)
plt.ylabel('Fraud (%)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_15_2= (
    all_data['ClmDiagnosisCode_2']
    .value_counts()
    .head(15)
    .index
)
df_top15 = all_data[all_data['ClmDiagnosisCode_2'].isin(top_15_2)]
diag_summary = (
    df_top15
    .groupby('ClmDiagnosisCode_2')['FraudFlag']
    .agg(
        total='count',
        fraud_count='sum'
    )
    .reset_index()
)
diag_summary['fraud_percent'] = (diag_summary['fraud_count'] / diag_summary['total']) * 100
diag_summary = diag_summary.sort_values(by='fraud_percent', ascending=False)
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.barplot(
    data=diag_summary,
    x='ClmDiagnosisCode_2',
    y='fraud_percent',
    palette='viridis'
)
plt.title('Procent fraudów w top 15 diagnozach (ClmDiagnosisCode_2)', fontsize=14)
plt.xlabel('Kod diagnozy', fontsize=12)
plt.ylabel('Fraud (%)', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Analiza fraudów według lekarzy (AttendingPhysician, OperatingPhysician, OtherPhysician)
# Top 10 lekarzy z największą liczbą fraudów
top_phys_frauds = all_data[all_data['PotentialFraud'] == 'Yes'] \
    ['AttendingPhysician'].value_counts().head(10)
print(top_phys_frauds)
top_phys_ids = top_phys_frauds.index.tolist()
top_phys_data = all_data[all_data['AttendingPhysician'].isin(top_phys_ids)]
# Out:
# AttendingPhysician
# PHY330576    2534
# PHY350277    1628
# PHY412132    1321
# PHY423534    1223
# PHY314027    1200
# PHY327046    1181
# PHY338032    1158
# PHY357120    1156
# PHY337425    1156
# PHY341578    1133
# Name: count, dtype: int64

# %%
fraud_phys_data = all_data[
    (all_data['PotentialFraud'] == 'Yes') &
    (all_data['AttendingPhysician'].isin(top_phys_ids))
]
fraud_diag_crosstab = pd.crosstab(fraud_phys_data['AttendingPhysician'], fraud_phys_data['ClmAdmitDiagnosisCode'])

# Wyciągnij top 15 najczęstszych kodów diagnozy wśród tych lekarzy
top_diag_codes = fraud_phys_data['ClmAdmitDiagnosisCode'].value_counts().head(15).index
# Filtrowanie tabeli tylko do tych kodów
filtered_crosstab = fraud_diag_crosstab[top_diag_codes]

plt.figure(figsize=(12, 6))
sns.heatmap(filtered_crosstab, cmap='YlOrBr', annot=True, fmt='d', linewidths=0.5, cbar_kws={'label': 'Liczba przypadków'})
plt.title("Top 15 kodów diagnoz u lekarzy podejrzanych o fraud")
plt.xlabel("Kod diagnozy przy przyjęciu")
plt.ylabel("AttendingPhysician")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
print('########################')
# Out:
# ########################

# %%
##### przygotowanie

all_data["RenalDiseaseIndicator2"] = all_data["RenalDiseaseIndicator"].map({
    "Y": 1,
    "N": 0,
    "0": np.nan
})

kolumny = [
    'InscClaimAmtReimbursed',
    'NoOfMonths_PartACov',
    'NoOfMonths_PartBCov',
    'IPAnnualReimbursementAmt',
    'IPAnnualDeductibleAmt',
    'OPAnnualReimbursementAmt',
    'OPAnnualDeductibleAmt',
    'Age',
    'DiagnosisCount',
    'ProceduresCount',
    'WasOperated',
    'Gender',
    'Race',
    'RenalDiseaseIndicator2'
]

X = all_data[kolumny]
y = all_data['FraudFlag']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

##### skalowanie
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

#####  treningowy i testowy
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, stratify=y, test_size=0.2, random_state=42
)


scale_pos_weight = sum(y_train == 0) / sum(y_train == 1)
print('done')
# Out:
# done

# %%
import gc ######### wywalony model ==>czyszczenie modelu
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score, f1_score

results = []
print('Start trenowania modeli...')

nm = 0
for maxd in range(1, 30):
    for lr in np.arange(0.01, 1, 0.05):  
        nm += 1
        print(f"\n➡️ Model {nm} | Parametry: max_depth = {maxd}, learning_rate = {lr:.2f}")
        
        model = XGBClassifier(
            objective='binary:logistic',
            eval_metric='logloss',
            scale_pos_weight=scale_pos_weight,
            random_state=42,
            max_depth=maxd,
            learning_rate=lr,
            tree_method='hist' 
        )
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]

        f1 = f1_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_prob)
        cm = confusion_matrix(y_test, y_pred)
        cr = classification_report(y_test, y_pred, digits=4)

        print(f"📊 F1 Score = {f1:.4f}, ROC AUC = {auc:.4f}")
        print(f"🧾 Confusion Matrix:\n{cm}")
        print(f"🧾 Classification Report:\n{cr}")

        results.append({
            'model_nr': nm,
            'max_depth': maxd,
            'learning_rate': lr,
            'f1': f1,
            'roc_auc': auc,
            'conf_matrix': cm,
            'class_report': cr,
            'model': model
        })

        del model   ####==>czyszczenie modelu
        gc.collect()

### the best model
results_df = pd.DataFrame(results)
best_row = results_df.sort_values(by='roc_auc', ascending=False).iloc[0]
best_model = best_row['model']


print('Koniec trenowania')
# Out:
# Start trenowania modeli...
#
# ➡️ Model 1 | Parametry: max_depth = 1, learning_rate = 0.01
# 📊 F1 Score = 0.1887, ROC AUC = 0.5274
# 🧾 Confusion Matrix:
# [[64912  4171]
#  [37693  4867]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6326    0.9396    0.7562     69083
#            1     0.5385    0.1144    0.1887     42560
#
#     accuracy                         0.6250    111643
#    macro avg     0.5856    0.5270    0.4724    111643
# weighted avg     0.5968    0.6250    0.5398    111643
#
#
# ➡️ Model 2 | Parametry: max_depth = 1, learning_rate = 0.06
# 📊 F1 Score = 0.2722, ROC AUC = 0.5369
# 🧾 Confusion Matrix:
# [[60872  8211]
#  [34562  7998]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6378    0.8811    0.7400     69083
#            1     0.4934    0.1879    0.2722     42560
#
#     accuracy                         0.6169    111643
#    macro avg     0.5656    0.5345    0.5061    111643
# weighted avg     0.5828    0.6169    0.5617    111643
#
#
# ➡️ Model 3 | Parametry: max_depth = 1, learning_rate = 0.11
# 📊 F1 Score = 0.2735, ROC AUC = 0.5389
# 🧾 Confusion Matrix:
# [[60797  8286]
#  [34505  8055]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6379    0.8801    0.7397     69083
#            1     0.4929    0.1893    0.2735     42560
#
#     accuracy                         0.6167    111643
#    macro avg     0.5654    0.5347    0.5066    111643
# weighted avg     0.5827    0.6167    0.5620    111643
#
#
# ➡️ Model 4 | Parametry: max_depth = 1, learning_rate = 0.16
# 📊 F1 Score = 0.2825, ROC AUC = 0.5406
# 🧾 Confusion Matrix:
# [[60092  8991]
#  [34081  8479]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6381    0.8699    0.7362     69083
#            1     0.4853    0.1992    0.2825     42560
#
#     accuracy                         0.6142    111643
#    macro avg     0.5617    0.5345    0.5093    111643
# weighted avg     0.5799    0.6142    0.5632    111643
#
#
# ➡️ Model 5 | Parametry: max_depth = 1, learning_rate = 0.21
# 📊 F1 Score = 0.2828, ROC AUC = 0.5418
# 🧾 Confusion Matrix:
# [[60063  9020]
#  [34065  8495]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6381    0.8694    0.7360     69083
#            1     0.4850    0.1996    0.2828     42560
#
#     accuracy                         0.6141    111643
#    macro avg     0.5616    0.5345    0.5094    111643
# weighted avg     0.5797    0.6141    0.5632    111643
#
#
# ➡️ Model 6 | Parametry: max_depth = 1, learning_rate = 0.26
# 📊 F1 Score = 0.2836, ROC AUC = 0.5417
# 🧾 Confusion Matrix:
# [[60026  9057]
#  [34032  8528]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6382    0.8689    0.7359     69083
#            1     0.4850    0.2004    0.2836     42560
#
#     accuracy                         0.6140    111643
#    macro avg     0.5616    0.5346    0.5097    111643
# weighted avg     0.5798    0.6140    0.5635    111643
#
#
# ➡️ Model 7 | Parametry: max_depth = 1, learning_rate = 0.31
# 📊 F1 Score = 0.2842, ROC AUC = 0.5421
# 🧾 Confusion Matrix:
# [[59984  9099]
#  [34004  8556]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6382    0.8683    0.7357     69083
#            1     0.4846    0.2010    0.2842     42560
#
#     accuracy                         0.6139    111643
#    macro avg     0.5614    0.5347    0.5099    111643
# weighted avg     0.5797    0.6139    0.5636    111643
#
#
# ➡️ Model 8 | Parametry: max_depth = 1, learning_rate = 0.36
# 📊 F1 Score = 0.2829, ROC AUC = 0.5424
# 🧾 Confusion Matrix:
# [[60082  9001]
#  [34065  8495]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6382    0.8697    0.7362     69083
#            1     0.4855    0.1996    0.2829     42560
#
#     accuracy                         0.6143    111643
#    macro avg     0.5619    0.5347    0.5095    111643
# weighted avg     0.5800    0.6143    0.5634    111643
#
#
# ➡️ Model 9 | Parametry: max_depth = 1, learning_rate = 0.41
# 📊 F1 Score = 0.2855, ROC AUC = 0.5428
# 🧾 Confusion Matrix:
# [[59901  9182]
#  [33943  8617]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6383    0.8671    0.7353     69083
#            1     0.4841    0.2025    0.2855     42560
#
#     accuracy                         0.6137    111643
#    macro avg     0.5612    0.5348    0.5104    111643
# weighted avg     0.5795    0.6137    0.5638    111643
#
#
# ➡️ Model 10 | Parametry: max_depth = 1, learning_rate = 0.46
# 📊 F1 Score = 0.2855, ROC AUC = 0.5435
# 🧾 Confusion Matrix:
# [[59885  9198]
#  [33940  8620]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6383    0.8669    0.7352     69083
#            1     0.4838    0.2025    0.2855     42560
#
#     accuracy                         0.6136    111643
#    macro avg     0.5610    0.5347    0.5104    111643
# weighted avg     0.5794    0.6136    0.5638    111643
#
#
# ➡️ Model 11 | Parametry: max_depth = 1, learning_rate = 0.51
# 📊 F1 Score = 0.2867, ROC AUC = 0.5437
# 🧾 Confusion Matrix:
# [[59783  9300]
#  [33883  8677]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6383    0.8654    0.7347     69083
#            1     0.4827    0.2039    0.2867     42560
#
#     accuracy                         0.6132    111643
#    macro avg     0.5605    0.5346    0.5107    111643
# weighted avg     0.5789    0.6132    0.5639    111643
#
#
# ➡️ Model 12 | Parametry: max_depth = 1, learning_rate = 0.56
# 📊 F1 Score = 0.2849, ROC AUC = 0.5442
# 🧾 Confusion Matrix:
# [[59971  9112]
#  [33978  8582]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6383    0.8681    0.7357     69083
#            1     0.4850    0.2016    0.2849     42560
#
#     accuracy                         0.6140    111643
#    macro avg     0.5617    0.5349    0.5103    111643
# weighted avg     0.5799    0.6140    0.5638    111643
#
#
# ➡️ Model 13 | Parametry: max_depth = 1, learning_rate = 0.61
# 📊 F1 Score = 0.2871, ROC AUC = 0.5447
# 🧾 Confusion Matrix:
# [[59808  9275]
#  [33871  8689]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6384    0.8657    0.7349     69083
#            1     0.4837    0.2042    0.2871     42560
#
#     accuracy                         0.6135    111643
#    macro avg     0.5611    0.5350    0.5110    111643
# weighted avg     0.5794    0.6135    0.5642    111643
#
#
# ➡️ Model 14 | Parametry: max_depth = 1, learning_rate = 0.66
# 📊 F1 Score = 0.2863, ROC AUC = 0.5452
# 🧾 Confusion Matrix:
# [[59891  9192]
#  [33913  8647]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6385    0.8669    0.7354     69083
#            1     0.4847    0.2032    0.2863     42560
#
#     accuracy                         0.6139    111643
#    macro avg     0.5616    0.5351    0.5108    111643
# weighted avg     0.5799    0.6139    0.5642    111643
#
#
# ➡️ Model 15 | Parametry: max_depth = 1, learning_rate = 0.71
# 📊 F1 Score = 0.2857, ROC AUC = 0.5463
# 🧾 Confusion Matrix:
# [[59901  9182]
#  [33938  8622]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6383    0.8671    0.7353     69083
#            1     0.4843    0.2026    0.2857     42560
#
#     accuracy                         0.6138    111643
#    macro avg     0.5613    0.5348    0.5105    111643
# weighted avg     0.5796    0.6138    0.5639    111643
#
#
# ➡️ Model 16 | Parametry: max_depth = 1, learning_rate = 0.76
# 📊 F1 Score = 0.2827, ROC AUC = 0.5465
# 🧾 Confusion Matrix:
# [[60190  8893]
#  [34089  8471]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6384    0.8713    0.7369     69083
#            1     0.4878    0.1990    0.2827     42560
#
#     accuracy                         0.6150    111643
#    macro avg     0.5631    0.5352    0.5098    111643
# weighted avg     0.5810    0.6150    0.5638    111643
#
#
# ➡️ Model 17 | Parametry: max_depth = 1, learning_rate = 0.81
# 📊 F1 Score = 0.2804, ROC AUC = 0.5469
# 🧾 Confusion Matrix:
# [[60474  8609]
#  [34218  8342]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6386    0.8754    0.7385     69083
#            1     0.4921    0.1960    0.2804     42560
#
#     accuracy                         0.6164    111643
#    macro avg     0.5654    0.5357    0.5094    111643
# weighted avg     0.5828    0.6164    0.5638    111643
#
#
# ➡️ Model 18 | Parametry: max_depth = 1, learning_rate = 0.86
# 📊 F1 Score = 0.2805, ROC AUC = 0.5464
# 🧾 Confusion Matrix:
# [[60547  8536]
#  [34225  8335]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6389    0.8764    0.7390     69083
#            1     0.4940    0.1958    0.2805     42560
#
#     accuracy                         0.6170    111643
#    macro avg     0.5665    0.5361    0.5098    111643
# weighted avg     0.5837    0.6170    0.5642    111643
#
#
# ➡️ Model 19 | Parametry: max_depth = 1, learning_rate = 0.91
# 📊 F1 Score = 0.2795, ROC AUC = 0.5474
# 🧾 Confusion Matrix:
# [[60655  8428]
#  [34278  8282]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6389    0.8780    0.7396     69083
#            1     0.4956    0.1946    0.2795     42560
#
#     accuracy                         0.6175    111643
#    macro avg     0.5673    0.5363    0.5095    111643
# weighted avg     0.5843    0.6175    0.5642    111643
#
#
# ➡️ Model 20 | Parametry: max_depth = 1, learning_rate = 0.96
# 📊 F1 Score = 0.2854, ROC AUC = 0.5477
# 🧾 Confusion Matrix:
# [[60138  8945]
#  [33988  8572]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6389    0.8705    0.7369     69083
#            1     0.4894    0.2014    0.2854     42560
#
#     accuracy                         0.6154    111643
#    macro avg     0.5641    0.5360    0.5112    111643
# weighted avg     0.5819    0.6154    0.5648    111643
#
#
# ➡️ Model 21 | Parametry: max_depth = 2, learning_rate = 0.01
# 📊 F1 Score = 0.2545, ROC AUC = 0.5358
# 🧾 Confusion Matrix:
# [[62139  6944]
#  [35342  7218]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6374    0.8995    0.7461     69083
#            1     0.5097    0.1696    0.2545     42560
#
#     accuracy                         0.6212    111643
#    macro avg     0.5736    0.5345    0.5003    111643
# weighted avg     0.5887    0.6212    0.5587    111643
#
#
# ➡️ Model 22 | Parametry: max_depth = 2, learning_rate = 0.06
# 📊 F1 Score = 0.2646, ROC AUC = 0.5454
# 🧾 Confusion Matrix:
# [[61525  7558]
#  [34919  7641]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6379    0.8906    0.7434     69083
#            1     0.5027    0.1795    0.2646     42560
#
#     accuracy                         0.6195    111643
#    macro avg     0.5703    0.5351    0.5040    111643
# weighted avg     0.5864    0.6195    0.5609    111643
#
#
# ➡️ Model 23 | Parametry: max_depth = 2, learning_rate = 0.11
# 📊 F1 Score = 0.2713, ROC AUC = 0.5502
# 🧾 Confusion Matrix:
# [[61251  7832]
#  [34651  7909]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6387    0.8866    0.7425     69083
#            1     0.5024    0.1858    0.2713     42560
#
#     accuracy                         0.6195    111643
#    macro avg     0.5706    0.5362    0.5069    111643
# weighted avg     0.5867    0.6195    0.5629    111643
#
#
# ➡️ Model 24 | Parametry: max_depth = 2, learning_rate = 0.16
# 📊 F1 Score = 0.2744, ROC AUC = 0.5513
# 🧾 Confusion Matrix:
# [[61034  8049]
#  [34514  8046]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6388    0.8835    0.7415     69083
#            1     0.4999    0.1891    0.2744     42560
#
#     accuracy                         0.6188    111643
#    macro avg     0.5693    0.5363    0.5079    111643
# weighted avg     0.5858    0.6188    0.5634    111643
#
#
# ➡️ Model 25 | Parametry: max_depth = 2, learning_rate = 0.21
# 📊 F1 Score = 0.2841, ROC AUC = 0.5521
# 🧾 Confusion Matrix:
# [[60482  8601]
#  [34091  8469]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6395    0.8755    0.7391     69083
#            1     0.4961    0.1990    0.2841     42560
#
#     accuracy                         0.6176    111643
#    macro avg     0.5678    0.5372    0.5116    111643
# weighted avg     0.5849    0.6176    0.5657    111643
#
#
# ➡️ Model 26 | Parametry: max_depth = 2, learning_rate = 0.26
# 📊 F1 Score = 0.2886, ROC AUC = 0.5528
# 🧾 Confusion Matrix:
# [[60249  8834]
#  [33892  8668]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6400    0.8721    0.7382     69083
#            1     0.4953    0.2037    0.2886     42560
#
#     accuracy                         0.6173    111643
#    macro avg     0.5676    0.5379    0.5134    111643
# weighted avg     0.5848    0.6173    0.5668    111643
#
#
# ➡️ Model 27 | Parametry: max_depth = 2, learning_rate = 0.31
# 📊 F1 Score = 0.2882, ROC AUC = 0.5525
# 🧾 Confusion Matrix:
# [[60148  8935]
#  [33889  8671]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6396    0.8707    0.7375     69083
#            1     0.4925    0.2037    0.2882     42560
#
#     accuracy                         0.6164    111643
#    macro avg     0.5661    0.5372    0.5129    111643
# weighted avg     0.5835    0.6164    0.5662    111643
#
#
# ➡️ Model 28 | Parametry: max_depth = 2, learning_rate = 0.36
# 📊 F1 Score = 0.3022, ROC AUC = 0.5535
# 🧾 Confusion Matrix:
# [[59258  9825]
#  [33237  9323]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6407    0.8578    0.7335     69083
#            1     0.4869    0.2191    0.3022     42560
#
#     accuracy                         0.6143    111643
#    macro avg     0.5638    0.5384    0.5178    111643
# weighted avg     0.5820    0.6143    0.5691    111643
#
#
# ➡️ Model 29 | Parametry: max_depth = 2, learning_rate = 0.41
# 📊 F1 Score = 0.3128, ROC AUC = 0.5534
# 🧾 Confusion Matrix:
# [[58458 10625]
#  [32701  9859]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6413    0.8462    0.7296     69083
#            1     0.4813    0.2316    0.3128     42560
#
#     accuracy                         0.6119    111643
#    macro avg     0.5613    0.5389    0.5212    111643
# weighted avg     0.5803    0.6119    0.5707    111643
#
#
# ➡️ Model 30 | Parametry: max_depth = 2, learning_rate = 0.46
# 📊 F1 Score = 0.3073, ROC AUC = 0.5534
# 🧾 Confusion Matrix:
# [[58751 10332]
#  [32957  9603]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6406    0.8504    0.7308     69083
#            1     0.4817    0.2256    0.3073     42560
#
#     accuracy                         0.6123    111643
#    macro avg     0.5612    0.5380    0.5190    111643
# weighted avg     0.5801    0.6123    0.5693    111643
#
#
# ➡️ Model 31 | Parametry: max_depth = 2, learning_rate = 0.51
# 📊 F1 Score = 0.3109, ROC AUC = 0.5535
# 🧾 Confusion Matrix:
# [[58542 10541]
#  [32787  9773]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6410    0.8474    0.7299     69083
#            1     0.4811    0.2296    0.3109     42560
#
#     accuracy                         0.6119    111643
#    macro avg     0.5610    0.5385    0.5204    111643
# weighted avg     0.5800    0.6119    0.5702    111643
#
#
# ➡️ Model 32 | Parametry: max_depth = 2, learning_rate = 0.56
# 📊 F1 Score = 0.3162, ROC AUC = 0.5534
# 🧾 Confusion Matrix:
# [[57973 11110]
#  [32480 10080]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6409    0.8392    0.7268     69083
#            1     0.4757    0.2368    0.3162     42560
#
#     accuracy                         0.6096    111643
#    macro avg     0.5583    0.5380    0.5215    111643
# weighted avg     0.5779    0.6096    0.5703    111643
#
#
# ➡️ Model 33 | Parametry: max_depth = 2, learning_rate = 0.61
# 📊 F1 Score = 0.3175, ROC AUC = 0.5532
# 🧾 Confusion Matrix:
# [[57936 11147]
#  [32426 10134]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6412    0.8386    0.7267     69083
#            1     0.4762    0.2381    0.3175     42560
#
#     accuracy                         0.6097    111643
#    macro avg     0.5587    0.5384    0.5221    111643
# weighted avg     0.5783    0.6097    0.5707    111643
#
#
# ➡️ Model 34 | Parametry: max_depth = 2, learning_rate = 0.66
# 📊 F1 Score = 0.3273, ROC AUC = 0.5548
# 🧾 Confusion Matrix:
# [[57160 11923]
#  [31898 10662]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6418    0.8274    0.7229     69083
#            1     0.4721    0.2505    0.3273     42560
#
#     accuracy                         0.6075    111643
#    macro avg     0.5570    0.5390    0.5251    111643
# weighted avg     0.5771    0.6075    0.5721    111643
#
#
# ➡️ Model 35 | Parametry: max_depth = 2, learning_rate = 0.71
# 📊 F1 Score = 0.3292, ROC AUC = 0.5539
# 🧾 Confusion Matrix:
# [[56780 12303]
#  [31750 10810]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6414    0.8219    0.7205     69083
#            1     0.4677    0.2540    0.3292     42560
#
#     accuracy                         0.6054    111643
#    macro avg     0.5545    0.5380    0.5249    111643
# weighted avg     0.5752    0.6054    0.5713    111643
#
#
# ➡️ Model 36 | Parametry: max_depth = 2, learning_rate = 0.76
# 📊 F1 Score = 0.3400, ROC AUC = 0.5534
# 🧾 Confusion Matrix:
# [[55916 13167]
#  [31148 11412]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6422    0.8094    0.7162     69083
#            1     0.4643    0.2681    0.3400     42560
#
#     accuracy                         0.6031    111643
#    macro avg     0.5533    0.5388    0.5281    111643
# weighted avg     0.5744    0.6031    0.5728    111643
#
#
# ➡️ Model 37 | Parametry: max_depth = 2, learning_rate = 0.81
# 📊 F1 Score = 0.3339, ROC AUC = 0.5530
# 🧾 Confusion Matrix:
# [[56302 12781]
#  [31469 11091]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6415    0.8150    0.7179     69083
#            1     0.4646    0.2606    0.3339     42560
#
#     accuracy                         0.6036    111643
#    macro avg     0.5530    0.5378    0.5259    111643
# weighted avg     0.5740    0.6036    0.5715    111643
#
#
# ➡️ Model 38 | Parametry: max_depth = 2, learning_rate = 0.86
# 📊 F1 Score = 0.3483, ROC AUC = 0.5542
# 🧾 Confusion Matrix:
# [[54997 14086]
#  [30616 11944]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6424    0.7961    0.7110     69083
#            1     0.4589    0.2806    0.3483     42560
#
#     accuracy                         0.5996    111643
#    macro avg     0.5506    0.5384    0.5297    111643
# weighted avg     0.5724    0.5996    0.5727    111643
#
#
# ➡️ Model 39 | Parametry: max_depth = 2, learning_rate = 0.91
# 📊 F1 Score = 0.3399, ROC AUC = 0.5530
# 🧾 Confusion Matrix:
# [[55857 13226]
#  [31138 11422]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6421    0.8085    0.7158     69083
#            1     0.4634    0.2684    0.3399     42560
#
#     accuracy                         0.6026    111643
#    macro avg     0.5527    0.5385    0.5278    111643
# weighted avg     0.5740    0.6026    0.5725    111643
#
#
# ➡️ Model 40 | Parametry: max_depth = 2, learning_rate = 0.96
# 📊 F1 Score = 0.3441, ROC AUC = 0.5531
# 🧾 Confusion Matrix:
# [[55349 13734]
#  [30861 11699]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6420    0.8012    0.7128     69083
#            1     0.4600    0.2749    0.3441     42560
#
#     accuracy                         0.6006    111643
#    macro avg     0.5510    0.5380    0.5285    111643
# weighted avg     0.5726    0.6006    0.5723    111643
#
#
# ➡️ Model 41 | Parametry: max_depth = 3, learning_rate = 0.01
# 📊 F1 Score = 0.2541, ROC AUC = 0.5377
# 🧾 Confusion Matrix:
# [[62154  6929]
#  [35357  7203]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6374    0.8997    0.7462     69083
#            1     0.5097    0.1692    0.2541     42560
#
#     accuracy                         0.6212    111643
#    macro avg     0.5735    0.5345    0.5001    111643
# weighted avg     0.5887    0.6212    0.5586    111643
#
#
# ➡️ Model 42 | Parametry: max_depth = 3, learning_rate = 0.06
# 📊 F1 Score = 0.2698, ROC AUC = 0.5493
# 🧾 Confusion Matrix:
# [[61435  7648]
#  [34732  7828]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6388    0.8893    0.7435     69083
#            1     0.5058    0.1839    0.2698     42560
#
#     accuracy                         0.6204    111643
#    macro avg     0.5723    0.5366    0.5067    111643
# weighted avg     0.5881    0.6204    0.5629    111643
#
#
# ➡️ Model 43 | Parametry: max_depth = 3, learning_rate = 0.11
# 📊 F1 Score = 0.2784, ROC AUC = 0.5530
# 🧾 Confusion Matrix:
# [[60864  8219]
#  [34350  8210]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6392    0.8810    0.7409     69083
#            1     0.4997    0.1929    0.2784     42560
#
#     accuracy                         0.6187    111643
#    macro avg     0.5695    0.5370    0.5096    111643
# weighted avg     0.5861    0.6187    0.5646    111643
#
#
# ➡️ Model 44 | Parametry: max_depth = 3, learning_rate = 0.16
# 📊 F1 Score = 0.2830, ROC AUC = 0.5549
# 🧾 Confusion Matrix:
# [[60713  8370]
#  [34166  8394]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6399    0.8788    0.7406     69083
#            1     0.5007    0.1972    0.2830     42560
#
#     accuracy                         0.6190    111643
#    macro avg     0.5703    0.5380    0.5118    111643
# weighted avg     0.5868    0.6190    0.5661    111643
#
#
# ➡️ Model 45 | Parametry: max_depth = 3, learning_rate = 0.21
# 📊 F1 Score = 0.2955, ROC AUC = 0.5569
# 🧾 Confusion Matrix:
# [[60025  9058]
#  [33613  8947]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6410    0.8689    0.7378     69083
#            1     0.4969    0.2102    0.2955     42560
#
#     accuracy                         0.6178    111643
#    macro avg     0.5690    0.5396    0.5166    111643
# weighted avg     0.5861    0.6178    0.5691    111643
#
#
# ➡️ Model 46 | Parametry: max_depth = 3, learning_rate = 0.26
# 📊 F1 Score = 0.3079, ROC AUC = 0.5584
# 🧾 Confusion Matrix:
# [[59143  9940]
#  [33007  9553]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6418    0.8561    0.7336     69083
#            1     0.4901    0.2245    0.3079     42560
#
#     accuracy                         0.6153    111643
#    macro avg     0.5659    0.5403    0.5208    111643
# weighted avg     0.5840    0.6153    0.5713    111643
#
#
# ➡️ Model 47 | Parametry: max_depth = 3, learning_rate = 0.31
# 📊 F1 Score = 0.3072, ROC AUC = 0.5567
# 🧾 Confusion Matrix:
# [[59173  9910]
#  [33037  9523]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6417    0.8565    0.7337     69083
#            1     0.4900    0.2238    0.3072     42560
#
#     accuracy                         0.6153    111643
#    macro avg     0.5659    0.5402    0.5205    111643
# weighted avg     0.5839    0.6153    0.5711    111643
#
#
# ➡️ Model 48 | Parametry: max_depth = 3, learning_rate = 0.36
# 📊 F1 Score = 0.3190, ROC AUC = 0.5578
# 🧾 Confusion Matrix:
# [[58345 10738]
#  [32446 10114]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6426    0.8446    0.7299     69083
#            1     0.4850    0.2376    0.3190     42560
#
#     accuracy                         0.6132    111643
#    macro avg     0.5638    0.5411    0.5244    111643
# weighted avg     0.5826    0.6132    0.5732    111643
#
#
# ➡️ Model 49 | Parametry: max_depth = 3, learning_rate = 0.41
# 📊 F1 Score = 0.3264, ROC AUC = 0.5585
# 🧾 Confusion Matrix:
# [[57564 11519]
#  [32014 10546]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6426    0.8333    0.7256     69083
#            1     0.4780    0.2478    0.3264     42560
#
#     accuracy                         0.6101    111643
#    macro avg     0.5603    0.5405    0.5260    111643
# weighted avg     0.5798    0.6101    0.5734    111643
#
#
# ➡️ Model 50 | Parametry: max_depth = 3, learning_rate = 0.46
# 📊 F1 Score = 0.3396, ROC AUC = 0.5606
# 🧾 Confusion Matrix:
# [[56602 12481]
#  [31304 11256]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6439    0.8193    0.7211     69083
#            1     0.4742    0.2645    0.3396     42560
#
#     accuracy                         0.6078    111643
#    macro avg     0.5590    0.5419    0.5303    111643
# weighted avg     0.5792    0.6078    0.5756    111643
#
#
# ➡️ Model 51 | Parametry: max_depth = 3, learning_rate = 0.51
# 📊 F1 Score = 0.3376, ROC AUC = 0.5589
# 🧾 Confusion Matrix:
# [[56748 12335]
#  [31411 11149]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6437    0.8214    0.7218     69083
#            1     0.4747    0.2620    0.3376     42560
#
#     accuracy                         0.6082    111643
#    macro avg     0.5592    0.5417    0.5297    111643
# weighted avg     0.5793    0.6082    0.5753    111643
#
#
# ➡️ Model 52 | Parametry: max_depth = 3, learning_rate = 0.56
# 📊 F1 Score = 0.3515, ROC AUC = 0.5609
# 🧾 Confusion Matrix:
# [[55488 13595]
#  [30585 11975]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6447    0.8032    0.7153     69083
#            1     0.4683    0.2814    0.3515     42560
#
#     accuracy                         0.6043    111643
#    macro avg     0.5565    0.5423    0.5334    111643
# weighted avg     0.5774    0.6043    0.5766    111643
#
#
# ➡️ Model 53 | Parametry: max_depth = 3, learning_rate = 0.61
# 📊 F1 Score = 0.3558, ROC AUC = 0.5634
# 🧾 Confusion Matrix:
# [[55373 13710]
#  [30383 12177]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6457    0.8015    0.7152     69083
#            1     0.4704    0.2861    0.3558     42560
#
#     accuracy                         0.6051    111643
#    macro avg     0.5580    0.5438    0.5355    111643
# weighted avg     0.5789    0.6051    0.5782    111643
#
#
# ➡️ Model 54 | Parametry: max_depth = 3, learning_rate = 0.66
# 📊 F1 Score = 0.3666, ROC AUC = 0.5612
# 🧾 Confusion Matrix:
# [[54147 14936]
#  [29657 12903]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6461    0.7838    0.7083     69083
#            1     0.4635    0.3032    0.3666     42560
#
#     accuracy                         0.6006    111643
#    macro avg     0.5548    0.5435    0.5374    111643
# weighted avg     0.5765    0.6006    0.5780    111643
#
#
# ➡️ Model 55 | Parametry: max_depth = 3, learning_rate = 0.71
# 📊 F1 Score = 0.3628, ROC AUC = 0.5629
# 🧾 Confusion Matrix:
# [[54511 14572]
#  [29898 12662]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6458    0.7891    0.7103     69083
#            1     0.4649    0.2975    0.3628     42560
#
#     accuracy                         0.6017    111643
#    macro avg     0.5554    0.5433    0.5366    111643
# weighted avg     0.5768    0.6017    0.5778    111643
#
#
# ➡️ Model 56 | Parametry: max_depth = 3, learning_rate = 0.76
# 📊 F1 Score = 0.3748, ROC AUC = 0.5616
# 🧾 Confusion Matrix:
# [[53194 15889]
#  [29082 13478]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6465    0.7700    0.7029     69083
#            1     0.4590    0.3167    0.3748     42560
#
#     accuracy                         0.5972    111643
#    macro avg     0.5527    0.5433    0.5388    111643
# weighted avg     0.5750    0.5972    0.5778    111643
#
#
# ➡️ Model 57 | Parametry: max_depth = 3, learning_rate = 0.81
# 📊 F1 Score = 0.3745, ROC AUC = 0.5597
# 🧾 Confusion Matrix:
# [[53142 15941]
#  [29080 13480]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6463    0.7692    0.7024     69083
#            1     0.4582    0.3167    0.3745     42560
#
#     accuracy                         0.5967    111643
#    macro avg     0.5522    0.5430    0.5385    111643
# weighted avg     0.5746    0.5967    0.5774    111643
#
#
# ➡️ Model 58 | Parametry: max_depth = 3, learning_rate = 0.86
# 📊 F1 Score = 0.3810, ROC AUC = 0.5602
# 🧾 Confusion Matrix:
# [[52502 16581]
#  [28643 13917]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6470    0.7600    0.6990     69083
#            1     0.4563    0.3270    0.3810     42560
#
#     accuracy                         0.5949    111643
#    macro avg     0.5517    0.5435    0.5400    111643
# weighted avg     0.5743    0.5949    0.5777    111643
#
#
# ➡️ Model 59 | Parametry: max_depth = 3, learning_rate = 0.91
# 📊 F1 Score = 0.3767, ROC AUC = 0.5600
# 🧾 Confusion Matrix:
# [[52969 16114]
#  [28942 13618]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6467    0.7667    0.7016     69083
#            1     0.4580    0.3200    0.3767     42560
#
#     accuracy                         0.5964    111643
#    macro avg     0.5523    0.5434    0.5392    111643
# weighted avg     0.5748    0.5964    0.5778    111643
#
#
# ➡️ Model 60 | Parametry: max_depth = 3, learning_rate = 0.96
# 📊 F1 Score = 0.3773, ROC AUC = 0.5595
# 🧾 Confusion Matrix:
# [[52678 16405]
#  [28850 13710]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6461    0.7625    0.6995     69083
#            1     0.4553    0.3221    0.3773     42560
#
#     accuracy                         0.5946    111643
#    macro avg     0.5507    0.5423    0.5384    111643
# weighted avg     0.5734    0.5946    0.5767    111643
#
#
# ➡️ Model 61 | Parametry: max_depth = 4, learning_rate = 0.01
# 📊 F1 Score = 0.2605, ROC AUC = 0.5381
# 🧾 Confusion Matrix:
# [[61642  7441]
#  [35073  7487]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6374    0.8923    0.7436     69083
#            1     0.5015    0.1759    0.2605     42560
#
#     accuracy                         0.6192    111643
#    macro avg     0.5694    0.5341    0.5020    111643
# weighted avg     0.5856    0.6192    0.5594    111643
#
#
# ➡️ Model 62 | Parametry: max_depth = 4, learning_rate = 0.06
# 📊 F1 Score = 0.2701, ROC AUC = 0.5526
# 🧾 Confusion Matrix:
# [[61544  7539]
#  [34737  7823]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6392    0.8909    0.7443     69083
#            1     0.5092    0.1838    0.2701     42560
#
#     accuracy                         0.6213    111643
#    macro avg     0.5742    0.5373    0.5072    111643
# weighted avg     0.5897    0.6213    0.5636    111643
#
#
# ➡️ Model 63 | Parametry: max_depth = 4, learning_rate = 0.11
# 📊 F1 Score = 0.2860, ROC AUC = 0.5585
# 🧾 Confusion Matrix:
# [[60832  8251]
#  [34082  8478]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6409    0.8806    0.7419     69083
#            1     0.5068    0.1992    0.2860     42560
#
#     accuracy                         0.6208    111643
#    macro avg     0.5739    0.5399    0.5139    111643
# weighted avg     0.5898    0.6208    0.5681    111643
#
#
# ➡️ Model 64 | Parametry: max_depth = 4, learning_rate = 0.16
# 📊 F1 Score = 0.2997, ROC AUC = 0.5598
# 🧾 Confusion Matrix:
# [[59893  9190]
#  [33440  9120]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6417    0.8670    0.7375     69083
#            1     0.4981    0.2143    0.2997     42560
#
#     accuracy                         0.6182    111643
#    macro avg     0.5699    0.5406    0.5186    111643
# weighted avg     0.5870    0.6182    0.5706    111643
#
#
# ➡️ Model 65 | Parametry: max_depth = 4, learning_rate = 0.21
# 📊 F1 Score = 0.3172, ROC AUC = 0.5633
# 🧾 Confusion Matrix:
# [[58789 10294]
#  [32596  9964]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6433    0.8510    0.7327     69083
#            1     0.4919    0.2341    0.3172     42560
#
#     accuracy                         0.6158    111643
#    macro avg     0.5676    0.5426    0.5250    111643
# weighted avg     0.5856    0.6158    0.5743    111643
#
#
# ➡️ Model 66 | Parametry: max_depth = 4, learning_rate = 0.26
# 📊 F1 Score = 0.3329, ROC AUC = 0.5646
# 🧾 Confusion Matrix:
# [[57625 11458]
#  [31773 10787]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6446    0.8341    0.7272     69083
#            1     0.4849    0.2535    0.3329     42560
#
#     accuracy                         0.6128    111643
#    macro avg     0.5648    0.5438    0.5301    111643
# weighted avg     0.5837    0.6128    0.5769    111643
#
#
# ➡️ Model 67 | Parametry: max_depth = 4, learning_rate = 0.31
# 📊 F1 Score = 0.3409, ROC AUC = 0.5655
# 🧾 Confusion Matrix:
# [[56955 12128]
#  [31323 11237]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6452    0.8244    0.7239     69083
#            1     0.4809    0.2640    0.3409     42560
#
#     accuracy                         0.6108    111643
#    macro avg     0.5631    0.5442    0.5324    111643
# weighted avg     0.5826    0.6108    0.5779    111643
#
#
# ➡️ Model 68 | Parametry: max_depth = 4, learning_rate = 0.36
# 📊 F1 Score = 0.3550, ROC AUC = 0.5666
# 🧾 Confusion Matrix:
# [[55648 13435]
#  [30475 12085]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6461    0.8055    0.7171     69083
#            1     0.4736    0.2840    0.3550     42560
#
#     accuracy                         0.6067    111643
#    macro avg     0.5598    0.5447    0.5361    111643
# weighted avg     0.5803    0.6067    0.5791    111643
#
#
# ➡️ Model 69 | Parametry: max_depth = 4, learning_rate = 0.41
# 📊 F1 Score = 0.3670, ROC AUC = 0.5692
# 🧾 Confusion Matrix:
# [[54989 14094]
#  [29826 12734]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6483    0.7960    0.7146     69083
#            1     0.4747    0.2992    0.3670     42560
#
#     accuracy                         0.6066    111643
#    macro avg     0.5615    0.5476    0.5408    111643
# weighted avg     0.5821    0.6066    0.5821    111643
#
#
# ➡️ Model 70 | Parametry: max_depth = 4, learning_rate = 0.46
# 📊 F1 Score = 0.3677, ROC AUC = 0.5710
# 🧾 Confusion Matrix:
# [[55291 13792]
#  [29865 12695]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6493    0.8004    0.7170     69083
#            1     0.4793    0.2983    0.3677     42560
#
#     accuracy                         0.6090    111643
#    macro avg     0.5643    0.5493    0.5423    111643
# weighted avg     0.5845    0.6090    0.5838    111643
#
#
# ➡️ Model 71 | Parametry: max_depth = 4, learning_rate = 0.51
# 📊 F1 Score = 0.3703, ROC AUC = 0.5690
# 🧾 Confusion Matrix:
# [[54246 14837]
#  [29518 13042]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6476    0.7852    0.7098     69083
#            1     0.4678    0.3064    0.3703     42560
#
#     accuracy                         0.6027    111643
#    macro avg     0.5577    0.5458    0.5401    111643
# weighted avg     0.5791    0.6027    0.5804    111643
#
#
# ➡️ Model 72 | Parametry: max_depth = 4, learning_rate = 0.56
# 📊 F1 Score = 0.3777, ROC AUC = 0.5687
# 🧾 Confusion Matrix:
# [[53740 15343]
#  [29079 13481]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6489    0.7779    0.7076     69083
#            1     0.4677    0.3168    0.3777     42560
#
#     accuracy                         0.6021    111643
#    macro avg     0.5583    0.5473    0.5426    111643
# weighted avg     0.5798    0.6021    0.5818    111643
#
#
# ➡️ Model 73 | Parametry: max_depth = 4, learning_rate = 0.61
# 📊 F1 Score = 0.3914, ROC AUC = 0.5707
# 🧾 Confusion Matrix:
# [[52484 16599]
#  [28164 14396]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6508    0.7597    0.7010     69083
#            1     0.4645    0.3383    0.3914     42560
#
#     accuracy                         0.5991    111643
#    macro avg     0.5576    0.5490    0.5462    111643
# weighted avg     0.5798    0.5991    0.5830    111643
#
#
# ➡️ Model 74 | Parametry: max_depth = 4, learning_rate = 0.66
# 📊 F1 Score = 0.3873, ROC AUC = 0.5678
# 🧾 Confusion Matrix:
# [[52510 16573]
#  [28357 14203]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6493    0.7601    0.7004     69083
#            1     0.4615    0.3337    0.3873     42560
#
#     accuracy                         0.5976    111643
#    macro avg     0.5554    0.5469    0.5439    111643
# weighted avg     0.5777    0.5976    0.5810    111643
#
#
# ➡️ Model 75 | Parametry: max_depth = 4, learning_rate = 0.71
# 📊 F1 Score = 0.3985, ROC AUC = 0.5726
# 🧾 Confusion Matrix:
# [[51601 17482]
#  [27619 14941]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6514    0.7469    0.6959     69083
#            1     0.4608    0.3511    0.3985     42560
#
#     accuracy                         0.5960    111643
#    macro avg     0.5561    0.5490    0.5472    111643
# weighted avg     0.5787    0.5960    0.5825    111643
#
#
# ➡️ Model 76 | Parametry: max_depth = 4, learning_rate = 0.76
# 📊 F1 Score = 0.3930, ROC AUC = 0.5697
# 🧾 Confusion Matrix:
# [[51832 17251]
#  [27935 14625]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6498    0.7503    0.6964     69083
#            1     0.4588    0.3436    0.3930     42560
#
#     accuracy                         0.5953    111643
#    macro avg     0.5543    0.5470    0.5447    111643
# weighted avg     0.5770    0.5953    0.5807    111643
#
#
# ➡️ Model 77 | Parametry: max_depth = 4, learning_rate = 0.81
# 📊 F1 Score = 0.4012, ROC AUC = 0.5688
# 🧾 Confusion Matrix:
# [[50849 18234]
#  [27303 15257]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6506    0.7361    0.6907     69083
#            1     0.4556    0.3585    0.4012     42560
#
#     accuracy                         0.5921    111643
#    macro avg     0.5531    0.5473    0.5460    111643
# weighted avg     0.5763    0.5921    0.5804    111643
#
#
# ➡️ Model 78 | Parametry: max_depth = 4, learning_rate = 0.86
# 📊 F1 Score = 0.4104, ROC AUC = 0.5723
# 🧾 Confusion Matrix:
# [[50335 18748]
#  [26733 15827]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6531    0.7286    0.6888     69083
#            1     0.4578    0.3719    0.4104     42560
#
#     accuracy                         0.5926    111643
#    macro avg     0.5554    0.5502    0.5496    111643
# weighted avg     0.5786    0.5926    0.5827    111643
#
#
# ➡️ Model 79 | Parametry: max_depth = 4, learning_rate = 0.91
# 📊 F1 Score = 0.4069, ROC AUC = 0.5713
# 🧾 Confusion Matrix:
# [[50446 18637]
#  [26929 15631]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6520    0.7302    0.6889     69083
#            1     0.4561    0.3673    0.4069     42560
#
#     accuracy                         0.5919    111643
#    macro avg     0.5541    0.5487    0.5479    111643
# weighted avg     0.5773    0.5919    0.5814    111643
#
#
# ➡️ Model 80 | Parametry: max_depth = 4, learning_rate = 0.96
# 📊 F1 Score = 0.4119, ROC AUC = 0.5717
# 🧾 Confusion Matrix:
# [[49892 19191]
#  [26546 16014]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6527    0.7222    0.6857     69083
#            1     0.4549    0.3763    0.4119     42560
#
#     accuracy                         0.5903    111643
#    macro avg     0.5538    0.5492    0.5488    111643
# weighted avg     0.5773    0.5903    0.5813    111643
#
#
# ➡️ Model 81 | Parametry: max_depth = 5, learning_rate = 0.01
# 📊 F1 Score = 0.2515, ROC AUC = 0.5423
# 🧾 Confusion Matrix:
# [[62376  6707]
#  [35474  7086]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6375    0.9029    0.7473     69083
#            1     0.5137    0.1665    0.2515     42560
#
#     accuracy                         0.6222    111643
#    macro avg     0.5756    0.5347    0.4994    111643
# weighted avg     0.5903    0.6222    0.5583    111643
#
#
# ➡️ Model 82 | Parametry: max_depth = 5, learning_rate = 0.06
# 📊 F1 Score = 0.2769, ROC AUC = 0.5559
# 🧾 Confusion Matrix:
# [[61236  7847]
#  [34459  8101]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6399    0.8864    0.7433     69083
#            1     0.5080    0.1903    0.2769     42560
#
#     accuracy                         0.6211    111643
#    macro avg     0.5739    0.5384    0.5101    111643
# weighted avg     0.5896    0.6211    0.5655    111643
#
#
# ➡️ Model 83 | Parametry: max_depth = 5, learning_rate = 0.11
# 📊 F1 Score = 0.3110, ROC AUC = 0.5654
# 🧾 Confusion Matrix:
# [[59515  9568]
#  [32963  9597]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6436    0.8615    0.7367     69083
#            1     0.5008    0.2255    0.3110     42560
#
#     accuracy                         0.6190    111643
#    macro avg     0.5722    0.5435    0.5239    111643
# weighted avg     0.5891    0.6190    0.5744    111643
#
#
# ➡️ Model 84 | Parametry: max_depth = 5, learning_rate = 0.16
# 📊 F1 Score = 0.3260, ROC AUC = 0.5687
# 🧾 Confusion Matrix:
# [[58620 10463]
#  [32236 10324]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6452    0.8485    0.7330     69083
#            1     0.4967    0.2426    0.3260     42560
#
#     accuracy                         0.6175    111643
#    macro avg     0.5709    0.5456    0.5295    111643
# weighted avg     0.5886    0.6175    0.5778    111643
#
#
# ➡️ Model 85 | Parametry: max_depth = 5, learning_rate = 0.21
# 📊 F1 Score = 0.3455, ROC AUC = 0.5713
# 🧾 Confusion Matrix:
# [[57443 11640]
#  [31243 11317]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6477    0.8315    0.7282     69083
#            1     0.4930    0.2659    0.3455     42560
#
#     accuracy                         0.6159    111643
#    macro avg     0.5703    0.5487    0.5368    111643
# weighted avg     0.5887    0.6159    0.5823    111643
#
#
# ➡️ Model 86 | Parametry: max_depth = 5, learning_rate = 0.26
# 📊 F1 Score = 0.3521, ROC AUC = 0.5733
# 🧾 Confusion Matrix:
# [[56557 12526]
#  [30790 11770]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6475    0.8187    0.7231     69083
#            1     0.4844    0.2766    0.3521     42560
#
#     accuracy                         0.6120    111643
#    macro avg     0.5660    0.5476    0.5376    111643
# weighted avg     0.5853    0.6120    0.5817    111643
#
#
# ➡️ Model 87 | Parametry: max_depth = 5, learning_rate = 0.31
# 📊 F1 Score = 0.3672, ROC AUC = 0.5750
# 🧾 Confusion Matrix:
# [[55562 13521]
#  [29948 12612]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6498    0.8043    0.7188     69083
#            1     0.4826    0.2963    0.3672     42560
#
#     accuracy                         0.6106    111643
#    macro avg     0.5662    0.5503    0.5430    111643
# weighted avg     0.5860    0.6106    0.5848    111643
#
#
# ➡️ Model 88 | Parametry: max_depth = 5, learning_rate = 0.36
# 📊 F1 Score = 0.3873, ROC AUC = 0.5773
# 🧾 Confusion Matrix:
# [[53775 15308]
#  [28664 13896]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6523    0.7784    0.7098     69083
#            1     0.4758    0.3265    0.3873     42560
#
#     accuracy                         0.6061    111643
#    macro avg     0.5641    0.5525    0.5485    111643
# weighted avg     0.5850    0.6061    0.5868    111643
#
#
# ➡️ Model 89 | Parametry: max_depth = 5, learning_rate = 0.41
# 📊 F1 Score = 0.3953, ROC AUC = 0.5783
# 🧾 Confusion Matrix:
# [[52749 16334]
#  [28052 14508]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6528    0.7636    0.7039     69083
#            1     0.4704    0.3409    0.3953     42560
#
#     accuracy                         0.6024    111643
#    macro avg     0.5616    0.5522    0.5496    111643
# weighted avg     0.5833    0.6024    0.5862    111643
#
#
# ➡️ Model 90 | Parametry: max_depth = 5, learning_rate = 0.46
# 📊 F1 Score = 0.3925, ROC AUC = 0.5775
# 🧾 Confusion Matrix:
# [[52818 16265]
#  [28197 14363]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6520    0.7646    0.7038     69083
#            1     0.4689    0.3375    0.3925     42560
#
#     accuracy                         0.6017    111643
#    macro avg     0.5605    0.5510    0.5481    111643
# weighted avg     0.5822    0.6017    0.5851    111643
#
#
# ➡️ Model 91 | Parametry: max_depth = 5, learning_rate = 0.51
# 📊 F1 Score = 0.4035, ROC AUC = 0.5805
# 🧾 Confusion Matrix:
# [[52019 17064]
#  [27491 15069]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6542    0.7530    0.7002     69083
#            1     0.4690    0.3541    0.4035     42560
#
#     accuracy                         0.6009    111643
#    macro avg     0.5616    0.5535    0.5518    111643
# weighted avg     0.5836    0.6009    0.5871    111643
#
#
# ➡️ Model 92 | Parametry: max_depth = 5, learning_rate = 0.56
# 📊 F1 Score = 0.4064, ROC AUC = 0.5804
# 🧾 Confusion Matrix:
# [[51588 17495]
#  [27247 15313]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6544    0.7468    0.6975     69083
#            1     0.4667    0.3598    0.4064     42560
#
#     accuracy                         0.5992    111643
#    macro avg     0.5606    0.5533    0.5519    111643
# weighted avg     0.5829    0.5992    0.5865    111643
#
#
# ➡️ Model 93 | Parametry: max_depth = 5, learning_rate = 0.61
# 📊 F1 Score = 0.4151, ROC AUC = 0.5822
# 🧾 Confusion Matrix:
# [[50671 18412]
#  [26593 15967]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6558    0.7335    0.6925     69083
#            1     0.4644    0.3752    0.4151     42560
#
#     accuracy                         0.5969    111643
#    macro avg     0.5601    0.5543    0.5538    111643
# weighted avg     0.5829    0.5969    0.5867    111643
#
#
# ➡️ Model 94 | Parametry: max_depth = 5, learning_rate = 0.66
# 📊 F1 Score = 0.4173, ROC AUC = 0.5791
# 🧾 Confusion Matrix:
# [[50019 19064]
#  [26313 16247]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6553    0.7240    0.6879     69083
#            1     0.4601    0.3817    0.4173     42560
#
#     accuracy                         0.5936    111643
#    macro avg     0.5577    0.5529    0.5526    111643
# weighted avg     0.5809    0.5936    0.5848    111643
#
#
# ➡️ Model 95 | Parametry: max_depth = 5, learning_rate = 0.71
# 📊 F1 Score = 0.4167, ROC AUC = 0.5777
# 🧾 Confusion Matrix:
# [[49907 19176]
#  [26313 16247]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6548    0.7224    0.6869     69083
#            1     0.4587    0.3817    0.4167     42560
#
#     accuracy                         0.5925    111643
#    macro avg     0.5567    0.5521    0.5518    111643
# weighted avg     0.5800    0.5925    0.5839    111643
#
#
# ➡️ Model 96 | Parametry: max_depth = 5, learning_rate = 0.76
# 📊 F1 Score = 0.4257, ROC AUC = 0.5800
# 🧾 Confusion Matrix:
# [[49060 20023]
#  [25637 16923]]
# 🧾 Classification Report:
# ...
#               precision    recall  f1-score   support
#
#            0     0.6920    0.7045    0.6982     69083
#            1     0.5058    0.4910    0.4983     42560
#
#     accuracy                         0.6231    111643
#    macro avg     0.5989    0.5978    0.5983    111643
# weighted avg     0.6210    0.6231    0.6220    111643
#
#
# ➡️ Model 550 | Parametry: max_depth = 28, learning_rate = 0.46
# 📊 F1 Score = 0.4963, ROC AUC = 0.6407
# 🧾 Confusion Matrix:
# [[48664 20419]
#  [21776 20784]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6909    0.7044    0.6976     69083
#            1     0.5044    0.4883    0.4963     42560
#
#     accuracy                         0.6221    111643
#    macro avg     0.5976    0.5964    0.5969    111643
# weighted avg     0.6198    0.6221    0.6208    111643
#
#
# ➡️ Model 551 | Parametry: max_depth = 28, learning_rate = 0.51
# 📊 F1 Score = 0.4963, ROC AUC = 0.6387
# 🧾 Confusion Matrix:
# [[48724 20359]
#  [21796 20764]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6909    0.7053    0.6980     69083
#            1     0.5049    0.4879    0.4963     42560
#
#     accuracy                         0.6224    111643
#    macro avg     0.5979    0.5966    0.5971    111643
# weighted avg     0.6200    0.6224    0.6211    111643
#
#
# ➡️ Model 552 | Parametry: max_depth = 28, learning_rate = 0.56
# 📊 F1 Score = 0.4922, ROC AUC = 0.6353
# 🧾 Confusion Matrix:
# [[48565 20518]
#  [21971 20589]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6885    0.7030    0.6957     69083
#            1     0.5009    0.4838    0.4922     42560
#
#     accuracy                         0.6194    111643
#    macro avg     0.5947    0.5934    0.5939    111643
# weighted avg     0.6170    0.6194    0.6181    111643
#
#
# ➡️ Model 553 | Parametry: max_depth = 28, learning_rate = 0.61
# 📊 F1 Score = 0.4920, ROC AUC = 0.6355
# 🧾 Confusion Matrix:
# [[48476 20607]
#  [21950 20610]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6883    0.7017    0.6950     69083
#            1     0.5000    0.4843    0.4920     42560
#
#     accuracy                         0.6188    111643
#    macro avg     0.5942    0.5930    0.5935    111643
# weighted avg     0.6165    0.6188    0.6176    111643
#
#
# ➡️ Model 554 | Parametry: max_depth = 28, learning_rate = 0.66
# 📊 F1 Score = 0.4911, ROC AUC = 0.6332
# 🧾 Confusion Matrix:
# [[48515 20568]
#  [22014 20546]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6879    0.7023    0.6950     69083
#            1     0.4997    0.4828    0.4911     42560
#
#     accuracy                         0.6186    111643
#    macro avg     0.5938    0.5925    0.5930    111643
# weighted avg     0.6162    0.6186    0.6173    111643
#
#
# ➡️ Model 555 | Parametry: max_depth = 28, learning_rate = 0.71
# 📊 F1 Score = 0.4898, ROC AUC = 0.6317
# 🧾 Confusion Matrix:
# [[48300 20783]
#  [22014 20546]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6869    0.6992    0.6930     69083
#            1     0.4971    0.4828    0.4898     42560
#
#     accuracy                         0.6167    111643
#    macro avg     0.5920    0.5910    0.5914    111643
# weighted avg     0.6146    0.6167    0.6155    111643
#
#
# ➡️ Model 556 | Parametry: max_depth = 28, learning_rate = 0.76
# 📊 F1 Score = 0.4897, ROC AUC = 0.6308
# 🧾 Confusion Matrix:
# [[48319 20764]
#  [22027 20533]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6869    0.6994    0.6931     69083
#            1     0.4972    0.4824    0.4897     42560
#
#     accuracy                         0.6167    111643
#    macro avg     0.5920    0.5909    0.5914    111643
# weighted avg     0.6146    0.6167    0.6156    111643
#
#
# ➡️ Model 557 | Parametry: max_depth = 28, learning_rate = 0.81
# 📊 F1 Score = 0.4862, ROC AUC = 0.6290
# 🧾 Confusion Matrix:
# [[48224 20859]
#  [22189 20371]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6849    0.6981    0.6914     69083
#            1     0.4941    0.4786    0.4862     42560
#
#     accuracy                         0.6144    111643
#    macro avg     0.5895    0.5884    0.5888    111643
# weighted avg     0.6121    0.6144    0.6132    111643
#
#
# ➡️ Model 558 | Parametry: max_depth = 28, learning_rate = 0.86
# 📊 F1 Score = 0.4840, ROC AUC = 0.6261
# 🧾 Confusion Matrix:
# [[48144 20939]
#  [22287 20273]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6836    0.6969    0.6902     69083
#            1     0.4919    0.4763    0.4840     42560
#
#     accuracy                         0.6128    111643
#    macro avg     0.5877    0.5866    0.5871    111643
# weighted avg     0.6105    0.6128    0.6116    111643
#
#
# ➡️ Model 559 | Parametry: max_depth = 28, learning_rate = 0.91
# 📊 F1 Score = 0.4852, ROC AUC = 0.6260
# 🧾 Confusion Matrix:
# [[48194 20889]
#  [22235 20325]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6843    0.6976    0.6909     69083
#            1     0.4932    0.4776    0.4852     42560
#
#     accuracy                         0.6137    111643
#    macro avg     0.5887    0.5876    0.5881    111643
# weighted avg     0.6114    0.6137    0.6125    111643
#
#
# ➡️ Model 560 | Parametry: max_depth = 28, learning_rate = 0.96
# 📊 F1 Score = 0.4831, ROC AUC = 0.6243
# 🧾 Confusion Matrix:
# [[47938 21145]
#  [22272 20288]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6828    0.6939    0.6883     69083
#            1     0.4897    0.4767    0.4831     42560
#
#     accuracy                         0.6111    111643
#    macro avg     0.5862    0.5853    0.5857    111643
# weighted avg     0.6092    0.6111    0.6101    111643
#
#
# ➡️ Model 561 | Parametry: max_depth = 29, learning_rate = 0.01
# 📊 F1 Score = 0.4644, ROC AUC = 0.6320
# 🧾 Confusion Matrix:
# [[52557 16526]
#  [24690 17870]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6804    0.7608    0.7183     69083
#            1     0.5195    0.4199    0.4644     42560
#
#     accuracy                         0.6308    111643
#    macro avg     0.6000    0.5903    0.5914    111643
# weighted avg     0.6191    0.6308    0.6215    111643
#
#
# ➡️ Model 562 | Parametry: max_depth = 29, learning_rate = 0.06
# 📊 F1 Score = 0.5148, ROC AUC = 0.6550
# 🧾 Confusion Matrix:
# [[48936 20147]
#  [20822 21738]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7015    0.7084    0.7049     69083
#            1     0.5190    0.5108    0.5148     42560
#
#     accuracy                         0.6330    111643
#    macro avg     0.6103    0.6096    0.6099    111643
# weighted avg     0.6319    0.6330    0.6325    111643
#
#
# ➡️ Model 563 | Parametry: max_depth = 29, learning_rate = 0.11
# 📊 F1 Score = 0.5152, ROC AUC = 0.6580
# 🧾 Confusion Matrix:
# [[49104 19979]
#  [20860 21700]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7018    0.7108    0.7063     69083
#            1     0.5206    0.5099    0.5152     42560
#
#     accuracy                         0.6342    111643
#    macro avg     0.6112    0.6103    0.6107    111643
# weighted avg     0.6328    0.6342    0.6334    111643
#
#
# ➡️ Model 564 | Parametry: max_depth = 29, learning_rate = 0.16
# 📊 F1 Score = 0.5136, ROC AUC = 0.6539
# 🧾 Confusion Matrix:
# [[48868 20215]
#  [20871 21689]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7007    0.7074    0.7040     69083
#            1     0.5176    0.5096    0.5136     42560
#
#     accuracy                         0.6320    111643
#    macro avg     0.6092    0.6085    0.6088    111643
# weighted avg     0.6309    0.6320    0.6314    111643
#
#
# ➡️ Model 565 | Parametry: max_depth = 29, learning_rate = 0.21
# 📊 F1 Score = 0.5101, ROC AUC = 0.6526
# 🧾 Confusion Matrix:
# [[48745 20338]
#  [21028 21532]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6986    0.7056    0.7021     69083
#            1     0.5143    0.5059    0.5101     42560
#
#     accuracy                         0.6295    111643
#    macro avg     0.6064    0.6058    0.6061    111643
# weighted avg     0.6283    0.6295    0.6289    111643
#
#
# ➡️ Model 566 | Parametry: max_depth = 29, learning_rate = 0.26
# 📊 F1 Score = 0.5032, ROC AUC = 0.6462
# 🧾 Confusion Matrix:
# [[48857 20226]
#  [21453 21107]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6949    0.7072    0.7010     69083
#            1     0.5107    0.4959    0.5032     42560
#
#     accuracy                         0.6267    111643
#    macro avg     0.6028    0.6016    0.6021    111643
# weighted avg     0.6247    0.6267    0.6256    111643
#
#
# ➡️ Model 567 | Parametry: max_depth = 29, learning_rate = 0.31
# 📊 F1 Score = 0.5029, ROC AUC = 0.6452
# 🧾 Confusion Matrix:
# [[48704 20379]
#  [21418 21142]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6946    0.7050    0.6997     69083
#            1     0.5092    0.4968    0.5029     42560
#
#     accuracy                         0.6256    111643
#    macro avg     0.6019    0.6009    0.6013    111643
# weighted avg     0.6239    0.6256    0.6247    111643
#
#
# ➡️ Model 568 | Parametry: max_depth = 29, learning_rate = 0.36
# 📊 F1 Score = 0.4997, ROC AUC = 0.6435
# 🧾 Confusion Matrix:
# [[48819 20264]
#  [21635 20925]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6929    0.7067    0.6997     69083
#            1     0.5080    0.4917    0.4997     42560
#
#     accuracy                         0.6247    111643
#    macro avg     0.6005    0.5992    0.5997    111643
# weighted avg     0.6224    0.6247    0.6235    111643
#
#
# ➡️ Model 569 | Parametry: max_depth = 29, learning_rate = 0.41
# 📊 F1 Score = 0.4971, ROC AUC = 0.6408
# 🧾 Confusion Matrix:
# [[48814 20269]
#  [21778 20782]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6915    0.7066    0.6990     69083
#            1     0.5062    0.4883    0.4971     42560
#
#     accuracy                         0.6234    111643
#    macro avg     0.5989    0.5974    0.5980    111643
# weighted avg     0.6209    0.6234    0.6220    111643
#
#
# ➡️ Model 570 | Parametry: max_depth = 29, learning_rate = 0.46
# 📊 F1 Score = 0.4957, ROC AUC = 0.6390
# 🧾 Confusion Matrix:
# [[48543 20540]
#  [21765 20795]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6904    0.7027    0.6965     69083
#            1     0.5031    0.4886    0.4957     42560
#
#     accuracy                         0.6211    111643
#    macro avg     0.5968    0.5956    0.5961    111643
# weighted avg     0.6190    0.6211    0.6200    111643
#
#
# ➡️ Model 571 | Parametry: max_depth = 29, learning_rate = 0.51
# 📊 F1 Score = 0.4945, ROC AUC = 0.6373
# 🧾 Confusion Matrix:
# [[48569 20514]
#  [21840 20720]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6898    0.7031    0.6964     69083
#            1     0.5025    0.4868    0.4945     42560
#
#     accuracy                         0.6206    111643
#    macro avg     0.5962    0.5949    0.5955    111643
# weighted avg     0.6184    0.6206    0.6194    111643
#
#
# ➡️ Model 572 | Parametry: max_depth = 29, learning_rate = 0.56
# 📊 F1 Score = 0.4924, ROC AUC = 0.6357
# 🧾 Confusion Matrix:
# [[48589 20494]
#  [21964 20596]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6887    0.7033    0.6959     69083
#            1     0.5012    0.4839    0.4924     42560
#
#     accuracy                         0.6197    111643
#    macro avg     0.5950    0.5936    0.5942    111643
# weighted avg     0.6172    0.6197    0.6184    111643
#
#
# ➡️ Model 573 | Parametry: max_depth = 29, learning_rate = 0.61
# 📊 F1 Score = 0.4898, ROC AUC = 0.6337
# 🧾 Confusion Matrix:
# [[48535 20548]
#  [22093 20467]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6872    0.7026    0.6948     69083
#            1     0.4990    0.4809    0.4898     42560
#
#     accuracy                         0.6181    111643
#    macro avg     0.5931    0.5917    0.5923    111643
# weighted avg     0.6155    0.6181    0.6166    111643
#
#
# ➡️ Model 574 | Parametry: max_depth = 29, learning_rate = 0.66
# 📊 F1 Score = 0.4926, ROC AUC = 0.6343
# 🧾 Confusion Matrix:
# [[48533 20550]
#  [21935 20625]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6887    0.7025    0.6956     69083
#            1     0.5009    0.4846    0.4926     42560
#
#     accuracy                         0.6195    111643
#    macro avg     0.5948    0.5936    0.5941    111643
# weighted avg     0.6171    0.6195    0.6182    111643
#
#
# ➡️ Model 575 | Parametry: max_depth = 29, learning_rate = 0.71
# 📊 F1 Score = 0.4899, ROC AUC = 0.6312
# 🧾 Confusion Matrix:
# [[48335 20748]
#  [22024 20536]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6870    0.6997    0.6933     69083
#            1     0.4974    0.4825    0.4899     42560
#
#     accuracy                         0.6169    111643
#    macro avg     0.5922    0.5911    0.5916    111643
# weighted avg     0.6147    0.6169    0.6157    111643
#
#
# ➡️ Model 576 | Parametry: max_depth = 29, learning_rate = 0.76
# 📊 F1 Score = 0.4872, ROC AUC = 0.6295
# 🧾 Confusion Matrix:
# [[48330 20753]
#  [22170 20390]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6855    0.6996    0.6925     69083
#            1     0.4956    0.4791    0.4872     42560
#
#     accuracy                         0.6155    111643
#    macro avg     0.5906    0.5893    0.5898    111643
# weighted avg     0.6131    0.6155    0.6142    111643
#
#
# ➡️ Model 577 | Parametry: max_depth = 29, learning_rate = 0.81
# 📊 F1 Score = 0.4879, ROC AUC = 0.6294
# 🧾 Confusion Matrix:
# [[48303 20780]
#  [22120 20440]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6859    0.6992    0.6925     69083
#            1     0.4959    0.4803    0.4879     42560
#
#     accuracy                         0.6157    111643
#    macro avg     0.5909    0.5897    0.5902    111643
# weighted avg     0.6135    0.6157    0.6145    111643
#
#
# ➡️ Model 578 | Parametry: max_depth = 29, learning_rate = 0.86
# 📊 F1 Score = 0.4852, ROC AUC = 0.6258
# 🧾 Confusion Matrix:
# [[48196 20887]
#  [22235 20325]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6843    0.6977    0.6909     69083
#            1     0.4932    0.4776    0.4852     42560
#
#     accuracy                         0.6138    111643
#    macro avg     0.5887    0.5876    0.5881    111643
# weighted avg     0.6114    0.6138    0.6125    111643
#
#
# ➡️ Model 579 | Parametry: max_depth = 29, learning_rate = 0.91
# 📊 F1 Score = 0.4866, ROC AUC = 0.6268
# 🧾 Confusion Matrix:
# [[48290 20793]
#  [22189 20371]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6852    0.6990    0.6920     69083
#            1     0.4949    0.4786    0.4866     42560
#
#     accuracy                         0.6150    111643
#    macro avg     0.5900    0.5888    0.5893    111643
# weighted avg     0.6126    0.6150    0.6137    111643
#
#
# ➡️ Model 580 | Parametry: max_depth = 29, learning_rate = 0.96
# 📊 F1 Score = 0.4846, ROC AUC = 0.6244
# 🧾 Confusion Matrix:
# [[48031 21052]
#  [22219 20341]]
# 🧾 Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6837    0.6953    0.6894     69083
#            1     0.4914    0.4779    0.4846     42560
#
#     accuracy                         0.6124    111643
#    macro avg     0.5876    0.5866    0.5870    111643
# weighted avg     0.6104    0.6124    0.6113    111643

# %%
##########    wybranie optymalnego modelu
y_pred_best = best_model.predict(X_test)
y_prob_best = best_model.predict_proba(X_test)[:, 1]
conf_best = confusion_matrix(y_test, y_pred_best)
report_best = classification_report(y_test, y_pred_best, digits=4)
f1_best = f1_score(y_test, y_pred_best)
roc_auc_best = roc_auc_score(y_test, y_prob_best)

print("\n====== ✅ NAJLEPSZY MODEL ======")
print(f"🔢 Model nr: {best_row['model_nr']}")
print(f"🛠 Max Depth: {best_row['max_depth']}")
print(f"⚙️ Learning Rate: {best_row['learning_rate']:.2f}")
print(f"🏅 ROC AUC: {roc_auc_best:.4f}")
print(f"🏅 F1 Score: {f1_best:.4f}")
print("\n🧾 Confusion Matrix:\n", conf_best)
print("\n🧾 Classification Report:\n", report_best)

#### wynik minialnie wyższy niz losowy
# Out:
# ====== ✅ NAJLEPSZY MODEL ======
# 🔢 Model nr: 563
# 🛠 Max Depth: 29
# ⚙️ Learning Rate: 0.11
# 🏅 ROC AUC: 0.6580
# 🏅 F1 Score: 0.5152
#
# 🧾 Confusion Matrix:
#  [[49104 19979]
#  [20860 21700]]
#
# 🧾 Classification Report:
#                precision    recall  f1-score   support
#
#            0     0.7018    0.7108    0.7063     69083
#            1     0.5206    0.5099    0.5152     42560
#
#     accuracy                         0.6342    111643
#    macro avg     0.6112    0.6103    0.6107    111643
# weighted avg     0.6328    0.6342    0.6334    111643

# %%
#########   sprawdzenie czy czy wyższe wartośći dają wyższe wyniki

plt.figure(figsize=(12, 6))
pivot_auc = results_df.pivot(index="max_depth", columns="learning_rate", values="roc_auc")
sns.heatmap(pivot_auc, annot=False, cmap="YlGnBu")
plt.title("ROC AUC w zależności od max_depth i learning_rate")
plt.xlabel("Learning Rate")
plt.ylabel("Max Depth")
plt.show()

plt.figure(figsize=(12, 6))
pivot_f1 = results_df.pivot(index="max_depth", columns="learning_rate", values="f1")
sns.heatmap(pivot_f1, annot=False, cmap="OrRd")
plt.title("F1 Score w zależności od max_depth i learning_rate")
plt.xlabel("Learning Rate")
plt.ylabel("Max Depth")
plt.show()

# %%
results_df["model_str"] = results_df["model"].astype(str)

plt.figure(figsize=(14, 6))
sns.barplot(data=results_df, x="model_str", y="f1", palette="coolwarm")
plt.title("F1 Score dla każdego modelu")
plt.xticks(rotation=45)
plt.ylabel("F1 Score")
plt.xlabel("Model")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\tolki\AppData\Local\Temp\ipykernel_1720\4265805509.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42, stratify=y_train)

# %%
import xgboost as xgb

# Konwersja danych do DMatrix
dtrain = xgb.DMatrix(X_tr, label=y_tr)
dval = xgb.DMatrix(X_val, label=y_val)

params = {
    "objective": "binary:logistic",
    "eval_metric": ["logloss", "auc"],
    "scale_pos_weight": scale_pos_weight,
    "max_depth": 29,
    "learning_rate": 0.11,
    "tree_method": "hist",
    "seed": 42
}

evals_result = {}

# Trenowanie z obserwacją
bst = xgb.train(
    params,
    dtrain,
    num_boost_round=500,
    evals=[(dtrain, "train"), (dval, "val")],
    early_stopping_rounds=10,
    evals_result=evals_result,
    verbose_eval=False
)

# %%
import matplotlib.pyplot as plt

#### wyniki wybranego modelu
#####

epochs = len(evals_result['train']['logloss'])
x_axis = range(epochs)

# Log Loss
plt.figure(figsize=(10, 5))
plt.plot(x_axis, evals_result['train']['logloss'], label='Train')
plt.plot(x_axis, evals_result['val']['logloss'], label='Validation')
plt.title("Log Loss podczas uczenia modelu")
plt.xlabel("Boosting Round")
plt.ylabel("Log Loss")
plt.legend()
plt.grid(True)
plt.show()

# AUC
plt.figure(figsize=(10, 5))
plt.plot(x_axis, evals_result['train']['auc'], label='Train AUC')
plt.plot(x_axis, evals_result['val']['auc'], label='Validation AUC')
plt.title("AUC podczas uczenia modelu")
plt.xlabel("Boosting Round")
plt.ylabel("AUC")
plt.legend()
plt.grid(True)
plt.show()
